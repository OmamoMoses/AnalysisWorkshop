# %% [markdown]
# <a href="https://colab.research.google.com/github/OmamoMoses/AnalysisWorkshop/blob/main/Vehicle_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import libraries
import requests
import pandas as pd
import pprint

# %%
def extract_api_enhanced(uri):
  """Description:
      Ingest json data from API endpoint
    Parameters:
      uri : URL of API endpoint where we are ingesting data from
    Returns:
      JSON data
      """
  print(f"Extracting data from {uri}")

  try:
    res = requests.get(uri)
    data = res.json()
  except Exception as e:
    print(f"Exception {e} while extracting data from {e}")
    data = res.status

  return data

# %% [markdown]
# ### 3. Vehicle API
#
# After a demonstration of ingesting data from this API, you are to attempt some exercises on ingesting data from the different endpoints in the API.
#
# https://vpic.nhtsa.dot.gov/api/

# %%
# Example 1 - Get all manufacturers

# we can still use our enhanced function by passing the entire query string

manufacturer_data = extract_api_enhanced("https://vpic.nhtsa.dot.gov/api/vehicles/getallmanufacturers?format=json&page=2")
pprint.pprint(manufacturer_data)
# Out:
# Extracting data from https://vpic.nhtsa.dot.gov/api/vehicles/getallmanufacturers?format=json&page=2
# {'Count': 100,
#  'Message': 'Response returned successfully',
#  'Results': [{'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': 'Toyota',
#               'Mfr_ID': 1090,
#               'Mfr_Name': 'TOYOTA MOTOR MANUFACTURING, TEXAS, INC.',
#               'VehicleTypes': []},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': 'Toyota',
#               'Mfr_ID': 1091,
#               'Mfr_Name': 'TOYOTA MOTOR MANUFACTURING, NORTHERN KENTUCKY, INC.',
#               'VehicleTypes': []},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': 'Thomas Grinding',
#               'Mfr_ID': 1092,
#               'Mfr_Name': 'THOMAS GRINDING INC.',
#               'VehicleTypes': [{'IsPrimary': True, 'Name': 'Trailer'}]},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': 'AM GENERAL',
#               'Mfr_ID': 1093,
#               'Mfr_Name': 'AM GENERAL CORPORATION ',
#               'VehicleTypes': [{'IsPrimary': False,
#                                 'Name': 'Multipurpose Passenger Vehicle '
#                                         '(MPV)'}]},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': 'Morgan Trailers',
#               'Mfr_ID': 1095,
#               'Mfr_Name': 'MORGAN TRAILERS, INC',
#               'VehicleTypes': [{'IsPrimary': True, 'Name': 'Trailer'}]},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': 'Altec',
#               'Mfr_ID': 1096,
#               'Mfr_Name': 'ALTEC ENVIRONMENTAL PRODUCTS, LLC',
#               'VehicleTypes': []},
#              {'Country': 'ENGLAND',
#               'Mfr_CommonName': 'Morgan 3 Wheeler',
#               'Mfr_ID': 1097,
#               'Mfr_Name': 'THE MORGAN 3 WHEELER LIMITED',
#               'VehicleTypes': []},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': 'Isuzu',
#               'Mfr_ID': 1098,
#               'Mfr_Name': 'ISUZU MANUFACTURING SERVICES OF AMERICA, INC.',
#               'VehicleTypes': []},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': 'Central Ohio Fabrication',
#               'Mfr_ID': 1099,
#               'Mfr_Name': 'CENTRAL OHIO FABRICATION LLC',
#               'VehicleTypes': [{'IsPrimary': True, 'Name': 'Trailer'}]},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': 'Thor Motor Coach',
#               'Mfr_ID': 1100,
#               'Mfr_Name': 'THOR MOTOR COACH INC.',
#               'VehicleTypes': []},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': None,
#               'Mfr_ID': 1101,
#               'Mfr_Name': 'THOR INDUSTRIES INC',
#               'VehicleTypes': [{'IsPrimary': True, 'Name': 'Trailer'},
#                                {'IsPrimary': False,
#                                 'Name': 'Multipurpose Passenger Vehicle '
#                                         '(MPV)'}]},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': 'Breckenridge',
#               'Mfr_ID': 1102,
#               'Mfr_Name': 'BRECKENRIDGE',
#               'VehicleTypes': []},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': 'Cruiser RV',
#               'Mfr_ID': 1104,
#               'Mfr_Name': 'CRUISER RV',
#               'VehicleTypes': [{'IsPrimary': True, 'Name': 'Trailer'}]},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': None,
#               'Mfr_ID': 1106,
#               'Mfr_Name': 'MVP RV INC. (THOR CALIFORNIA, INC.)',
#               'VehicleTypes': [{'IsPrimary': True, 'Name': 'Trailer'}]},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': 'Thor Manufacturing',
#               'Mfr_ID': 1107,
#               'Mfr_Name': 'THOR MANUFACTURING LLC',
#               'VehicleTypes': [{'IsPrimary': False, 'Name': 'Trailer'}]},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': 'Winnebago Of Indiana',
#               'Mfr_ID': 1108,
#               'Mfr_Name': 'WINNEBAGO OF INDIANA, LLC',
#               'VehicleTypes': [{'IsPrimary': True, 'Name': 'Trailer'}]},
#              {'Country': 'JAPAN',
#               'Mfr_CommonName': 'HINO TRUCKS',
#               'Mfr_ID': 1109,
#               'Mfr_Name': 'HINO MOTORS, LTD.',
#               'VehicleTypes': [{'IsPrimary': False, 'Name': 'Truck'},
#                                {'IsPrimary': False,
#                                 'Name': 'Incomplete Vehicle'}]},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': 'Supreme Corp.',
#               'Mfr_ID': 1110,
#               'Mfr_Name': 'SUPREME CORPORATION',
#               'VehicleTypes': [{'IsPrimary': True, 'Name': 'Truck'},
#                                {'IsPrimary': False, 'Name': 'Trailer'},
#                                {'IsPrimary': False,
#                                 'Name': 'Incomplete Vehicle'}]},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': 'KNAPHEIDE Truck',
#               'Mfr_ID': 1115,
#               'Mfr_Name': 'KNAPHEIDE TRUCK EQUIPMENT COMPANY SOUTHWEST',
#               'VehicleTypes': [{'IsPrimary': False, 'Name': 'Truck'}]},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': 'Collins Welding',
#               'Mfr_ID': 1116,
#               'Mfr_Name': 'COLLINS WELDING, INC.',
#               'VehicleTypes': [{'IsPrimary': True, 'Name': 'Trailer'}]},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': 'Gillig',
#               'Mfr_ID': 1118,
#               'Mfr_Name': 'GILLIG LLC',
#               'VehicleTypes': [{'IsPrimary': True, 'Name': 'Bus'}]},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': 'Champion Trike',
#               'Mfr_ID': 1119,
#               'Mfr_Name': 'CHAMPION TRIKE MANUFACTURING INC.',
#               'VehicleTypes': [{'IsPrimary': True, 'Name': 'Motorcycle'}]},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': None,
#               'Mfr_ID': 1120,
#               'Mfr_Name': 'CHAMPION TELECOM, INC.',
#               'VehicleTypes': [{'IsPrimary': False, 'Name': 'Trailer'}]},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': None,
#               'Mfr_ID': 1121,
#               'Mfr_Name': 'CHAMPION BRIDGE CO., INC.',
#               'VehicleTypes': [{'IsPrimary': False, 'Name': 'Trailer'}]},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': None,
#               'Mfr_ID': 1122,
#               'Mfr_Name': 'CHAMPION TRAILERS, INC.',
#               'VehicleTypes': [{'IsPrimary': False, 'Name': 'Trailer'}]},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': 'Micro-Lite Trailer',
#               'Mfr_ID': 1123,
#               'Mfr_Name': 'MICRO-LITE TRAILER MFG. LLC',
#               'VehicleTypes': []},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': 'PIERCE MANUFACTURING',
#               'Mfr_ID': 1124,
#               'Mfr_Name': 'PIERCE MANUFACTURING INC.',
#               'VehicleTypes': [{'IsPrimary': True, 'Name': 'Truck'}]},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': 'MCI',
#               'Mfr_ID': 1126,
#               'Mfr_Name': 'MOTOR COACH INDUSTRIES, INC.',
#               'VehicleTypes': [{'IsPrimary': True, 'Name': 'Bus'},
#                                {'IsPrimary': False,
#                                 'Name': 'Incomplete Vehicle'}]},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': None,
#               'Mfr_ID': 1127,
#               'Mfr_Name': 'TURTLEBACK TRAILERS LLC',
#               'VehicleTypes': [{'IsPrimary': False, 'Name': 'Trailer'}]},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': 'PREVOST',
#               'Mfr_ID': 1128,
#               'Mfr_Name': 'PREVOST CAR (US) INC.',
#               'VehicleTypes': [{'IsPrimary': True, 'Name': 'Bus'}]},
#              {'Country': 'TURKEY',
#               'Mfr_CommonName': 'TEMSA',
#               'Mfr_ID': 1129,
#               'Mfr_Name': 'TEMSA SKODA SABANCI ULASIM ARACLARI A.S.',
#               'VehicleTypes': [{'IsPrimary': False, 'Name': 'Bus'},
#                                {'IsPrimary': False,
#                                 'Name': 'Incomplete Vehicle'}]},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': 'Yamaha',
#               'Mfr_ID': 1130,
#               'Mfr_Name': 'YAMAHA MOTOR CORPORATION',
#               'VehicleTypes': [{'IsPrimary': True, 'Name': 'Motorcycle'}]},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': 'Triumph',
#               'Mfr_ID': 1131,
#               'Mfr_Name': 'TRIUMPH MOTORCYCLES (AMERICA) LIMITED',
#               'VehicleTypes': [{'IsPrimary': True, 'Name': 'Motorcycle'}]},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': 'Polaris',
#               'Mfr_ID': 1132,
#               'Mfr_Name': 'POLARIS INDUSTRIES INC.',
#               'VehicleTypes': [{'IsPrimary': True, 'Name': 'Motorcycle'},
#                                {'IsPrimary': False,
#                                 'Name': 'Low Speed Vehicle (LSV)'}]},
#              {'Country': 'ITALY',
#               'Mfr_CommonName': 'Ducati',
#               'Mfr_ID': 1133,
#               'Mfr_Name': 'DUCATI MOTOR HOLDING S.P.A. ',
#               'VehicleTypes': [{'IsPrimary': True, 'Name': 'Motorcycle'}]},
#              {'Country': 'CANADA',
#               'Mfr_CommonName': 'BRP',
#               'Mfr_ID': 1134,
#               'Mfr_Name': 'BOMBARDIER RECREATIONAL PRODUCTS INC ',
#               'VehicleTypes': [{'IsPrimary': False, 'Name': 'Motorcycle'},
#                                {'IsPrimary': False, 'Name': 'Trailer'},
#                                {'IsPrimary': True,
#                                 'Name': 'Low Speed Vehicle (LSV)'},
#                                {'IsPrimary': False,
#                                 'Name': 'Off Road Vehicle'}]},
#              {'Country': 'TAIWAN',
#               'Mfr_CommonName': 'Genuine Scooters',
#               'Mfr_ID': 1135,
#               'Mfr_Name': 'MOTIVE POWER INDUSTRY CO. LTD.',
#               'VehicleTypes': [{'IsPrimary': False, 'Name': 'Motorcycle'}]},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': None,
#               'Mfr_ID': 1136,
#               'Mfr_Name': 'GENUINE JACKS MANUFACTURING INC',
#               'VehicleTypes': [{'IsPrimary': True, 'Name': 'Trailer'}]},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': 'SAAB',
#               'Mfr_ID': 1137,
#               'Mfr_Name': 'SAAB CARS NORTH AMERICA, INC.',
#               'VehicleTypes': []},
#              {'Country': 'ITALY',
#               'Mfr_CommonName': 'Moto Guzzi',
#               'Mfr_ID': 1139,
#               'Mfr_Name': 'MOTO GUZZI S.P.A',
#               'VehicleTypes': [{'IsPrimary': True, 'Name': 'Motorcycle'}]},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': None,
#               'Mfr_ID': 1140,
#               'Mfr_Name': 'VICTORY SWEEPERS INC',
#               'VehicleTypes': []},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': None,
#               'Mfr_ID': 1141,
#               'Mfr_Name': 'VICTORY INDUSTRIAL PRODUCTS',
#               'VehicleTypes': [{'IsPrimary': True, 'Name': 'Trailer'}]},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': None,
#               'Mfr_ID': 1142,
#               'Mfr_Name': 'KTLL GROUP LLC DBA VICTORY TRAILERS',
#               'VehicleTypes': [{'IsPrimary': False, 'Name': 'Trailer'}]},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': None,
#               'Mfr_ID': 1144,
#               'Mfr_Name': 'ROCKET ROGERS VICTORY OLD 97 CHOPPERS INC',
#               'VehicleTypes': [{'IsPrimary': True, 'Name': 'Motorcycle'}]},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': 'Toyota',
#               'Mfr_ID': 1145,
#               'Mfr_Name': 'TOYOTA MOTOR MANUFACTURING, MISSISSIPPI, INC.',
#               'VehicleTypes': []},
#              {'Country': 'GERMANY',
#               'Mfr_CommonName': 'Daimler Chrysler',
#               'Mfr_ID': 1146,
#               'Mfr_Name': 'DAIMLER CHRYSLER AG',
#               'VehicleTypes': []},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': 'Volkswagen',
#               'Mfr_ID': 1147,
#               'Mfr_Name': 'VOLKSWAGEN GROUP OF AMERICA, INC.',
#               'VehicleTypes': [{'IsPrimary': False, 'Name': 'Passenger Car'},
#                                {'IsPrimary': True,
#                                 'Name': 'Multipurpose Passenger Vehicle '
#                                         '(MPV)'}]},
#              {'Country': 'GERMANY',
#               'Mfr_CommonName': 'Volkswagen',
#               'Mfr_ID': 1148,
#               'Mfr_Name': 'VOLKSWAGEN AG',
#               'VehicleTypes': [{'IsPrimary': False, 'Name': 'Passenger Car'},
#                                {'IsPrimary': False,
#                                 'Name': 'Multipurpose Passenger Vehicle '
#                                         '(MPV)'}]},
#              {'Country': 'GERMANY',
#               'Mfr_CommonName': 'Audi',
#               'Mfr_ID': 1149,
#               'Mfr_Name': 'AUDI AG',
#               'VehicleTypes': [{'IsPrimary': False, 'Name': 'Passenger Car'},
#                                {'IsPrimary': False,
#                                 'Name': 'Multipurpose Passenger Vehicle '
#                                         '(MPV)'}]},
#              {'Country': 'GERMANY',
#               'Mfr_CommonName': None,
#               'Mfr_ID': 1150,
#               'Mfr_Name': 'AUDI SPORT GMBH',
#               'VehicleTypes': [{'IsPrimary': False, 'Name': 'Passenger Car'},
#                                {'IsPrimary': False,
#                                 'Name': 'Multipurpose Passenger Vehicle '
#                                         '(MPV)'}]},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': 'Google Auto',
#               'Mfr_ID': 1151,
#               'Mfr_Name': 'GOOGLE AUTO LLC',
#               'VehicleTypes': [{'IsPrimary': True,
#                                 'Name': 'Low Speed Vehicle (LSV)'}]},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': 'Kawasaki',
#               'Mfr_ID': 1152,
#               'Mfr_Name': 'KAWASAKI MOTORS, LTD',
#               'VehicleTypes': [{'IsPrimary': True, 'Name': 'Motorcycle'}]},
#              {'Country': 'TAIWAN',
#               'Mfr_CommonName': 'Yamaha',
#               'Mfr_ID': 1153,
#               'Mfr_Name': 'YAMAHA MOTOR TAIWAN CO., LTD.',
#               'VehicleTypes': [{'IsPrimary': True, 'Name': 'Motorcycle'}]},
#              {'Country': 'FRANCE',
#               'Mfr_CommonName': 'Toyota',
#               'Mfr_ID': 1155,
#               'Mfr_Name': 'TOYOTA MOTOR MANUFACTURING, FRANCE, S.A.S.',
#               'VehicleTypes': []},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': 'Workhorse Manufacturing Inc',
#               'Mfr_ID': 1156,
#               'Mfr_Name': 'WORKHORSE MANUFACTURING, INC',
#               'VehicleTypes': []},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': 'Workhorse Water Trailer',
#               'Mfr_ID': 1157,
#               'Mfr_Name': 'WATERTRAILERS.NET, INC.',
#               'VehicleTypes': [{'IsPrimary': True, 'Name': 'Trailer'}]},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': None,
#               'Mfr_ID': 1158,
#               'Mfr_Name': 'WORKHORSE INDUSTRIES OF TEXAS',
#               'VehicleTypes': []},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': 'Shasta',
#               'Mfr_ID': 1159,
#               'Mfr_Name': 'SHASTA INDUSTRIES LLC',
#               'VehicleTypes': []},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': 'Buell',
#               'Mfr_ID': 1162,
#               'Mfr_Name': 'BUELL MOTORCYCLE COMPANY',
#               'VehicleTypes': []},
#              {'Country': 'BELGIUM',
#               'Mfr_CommonName': 'Van Hool',
#               'Mfr_ID': 1163,
#               'Mfr_Name': 'VAN HOOL N.V.',
#               'VehicleTypes': [{'IsPrimary': True, 'Name': 'Bus'},
#                                {'IsPrimary': False,
#                                 'Name': 'Incomplete Vehicle'}]},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': 'Volvo Bus (Mexico)',
#               'Mfr_ID': 1164,
#               'Mfr_Name': 'VOLVO INDUSTRIAL DE MEXICO, S.A. DE C.V.',
#               'VehicleTypes': [{'IsPrimary': True, 'Name': 'Bus'}]},
#              {'Country': 'BRAZIL',
#               'Mfr_CommonName': 'Busscar',
#               'Mfr_ID': 1166,
#               'Mfr_Name': 'BUSSCAR ONIBUS S.A.',
#               'VehicleTypes': [{'IsPrimary': True, 'Name': 'Bus'}]},
#              {'Country': 'CHINA',
#               'Mfr_CommonName': 'ZheJiang LingYun',
#               'Mfr_ID': 1167,
#               'Mfr_Name': 'ZHEJIANG LINGYUN MOTORCYCLE CO., LTD.',
#               'VehicleTypes': [{'IsPrimary': True, 'Name': 'Motorcycle'}]},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': 'KTMMEX ',
#               'Mfr_ID': 1168,
#               'Mfr_Name': 'KTMMEX SA. DE CV.',
#               'VehicleTypes': []},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': 'Ferrari',
#               'Mfr_ID': 1169,
#               'Mfr_Name': 'FERRARI NORTH AMERICA, INC.',
#               'VehicleTypes': [{'IsPrimary': True, 'Name': 'Passenger Car'},
#                                {'IsPrimary': False,
#                                 'Name': 'Multipurpose Passenger Vehicle '
#                                         '(MPV)'}]},
#              {'Country': 'JAPAN',
#               'Mfr_CommonName': 'Isuzu',
#               'Mfr_ID': 1171,
#               'Mfr_Name': 'ISUZU MOTORS LIMITED, JAPAN',
#               'VehicleTypes': [{'IsPrimary': False, 'Name': 'Passenger Car'},
#                                {'IsPrimary': False, 'Name': 'Truck'},
#                                {'IsPrimary': False,
#                                 'Name': 'Multipurpose Passenger Vehicle (MPV)'},
#                                {'IsPrimary': False,
#                                 'Name': 'Incomplete Vehicle'}]},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': 'BRECKENRIDGE PARK',
#               'Mfr_ID': 1173,
#               'Mfr_Name': 'DAMON CORPORATION',
#               'VehicleTypes': [{'IsPrimary': True,
#                                 'Name': 'Multipurpose Passenger Vehicle '
#                                         '(MPV)'}]},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': 'MOBILITY VENTURES',
#               'Mfr_ID': 1174,
#               'Mfr_Name': 'AM GENERAL LLC',
#               'VehicleTypes': [{'IsPrimary': False,
#                                 'Name': 'Multipurpose Passenger Vehicle '
#                                         '(MPV)'}]},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': 'Q3',
#               'Mfr_ID': 1175,
#               'Mfr_Name': 'O3 INDUSTRIES LLC',
#               'VehicleTypes': [{'IsPrimary': False, 'Name': 'Trailer'}]},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': '280 Trailers',
#               'Mfr_ID': 1176,
#               'Mfr_Name': '280 TRAILERS LLC',
#               'VehicleTypes': [{'IsPrimary': True, 'Name': 'Trailer'}]},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': '3D Custom Aluminum',
#               'Mfr_ID': 1177,
#               'Mfr_Name': '3D CUSTOM ALUMINUM, LLC',
#               'VehicleTypes': []},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': None,
#               'Mfr_ID': 1178,
#               'Mfr_Name': '3T MFG.',
#               'VehicleTypes': [{'IsPrimary': False, 'Name': 'Trailer'},
#                                {'IsPrimary': False,
#                                 'Name': 'Incomplete Vehicle'}]},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': '58th Street Customs',
#               'Mfr_ID': 1179,
#               'Mfr_Name': '58TH STREET CUSTOMS',
#               'VehicleTypes': []},
#              {'Country': 'CANADA',
#               'Mfr_CommonName': '9013-7233 Quebec',
#               'Mfr_ID': 1180,
#               'Mfr_Name': '9013-7233 QUEBEC INC.',
#               'VehicleTypes': [{'IsPrimary': False, 'Name': 'Trailer'}]},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': 'A&E Trailers',
#               'Mfr_ID': 1181,
#               'Mfr_Name': 'A & E TRAILERS',
#               'VehicleTypes': []},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': 'A&M Fabrications',
#               'Mfr_ID': 1182,
#               'Mfr_Name': 'A & M FABRICATIONS LLC',
#               'VehicleTypes': [{'IsPrimary': False, 'Name': 'Trailer'}]},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': 'Tow Master',
#               'Mfr_ID': 1183,
#               'Mfr_Name': 'A-1 CUSTOM TRAILER MFG., INC. ',
#               'VehicleTypes': [{'IsPrimary': False, 'Name': 'Trailer'}]},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': 'A to Z Auto Sales',
#               'Mfr_ID': 1184,
#               'Mfr_Name': 'A TO Z AUTO SALES',
#               'VehicleTypes': [{'IsPrimary': False, 'Name': 'Trailer'}]},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': 'Magnum Choppers',
#               'Mfr_ID': 1185,
#               'Mfr_Name': 'A UNIQUE CARS INC.',
#               'VehicleTypes': [{'IsPrimary': True, 'Name': 'Motorcycle'}]},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': 'A&A Manufacturing',
#               'Mfr_ID': 1186,
#               'Mfr_Name': 'A & A MANUFACTURING',
#               'VehicleTypes': [{'IsPrimary': False, 'Name': 'Trailer'}]},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': 'A. N. Bowling Manufacturing',
#               'Mfr_ID': 1187,
#               'Mfr_Name': 'A. N. BOWLING, MFG.',
#               'VehicleTypes': [{'IsPrimary': True, 'Name': 'Trailer'}]},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': 'A. Q. Manufacturing',
#               'Mfr_ID': 1188,
#               'Mfr_Name': 'A.Q. MANUFACTURING CORP.',
#               'VehicleTypes': [{'IsPrimary': True, 'Name': 'Trailer'}]},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': 'ARM INC',
#               'Mfr_ID': 1189,
#               'Mfr_Name': 'A.R.M.(U.S.A.), INC.',
#               'VehicleTypes': [{'IsPrimary': True, 'Name': 'Trailer'}]},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': 'A1 Cycles',
#               'Mfr_ID': 1191,
#               'Mfr_Name': 'A1 CYCLES INC.',
#               'VehicleTypes': [{'IsPrimary': True, 'Name': 'Motorcycle'}]},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': 'A-BAR-D',
#               'Mfr_ID': 1192,
#               'Mfr_Name': 'A-BAR-D MFG.',
#               'VehicleTypes': [{'IsPrimary': False, 'Name': 'Trailer'}]},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': 'ABASTECEDORA DE TRACTOPARTES Y REFACCIONES',
#               'Mfr_ID': 1193,
#               'Mfr_Name': 'ABASTECEDORA DE TRACTOPARTES Y REFACCIONES LLC',
#               'VehicleTypes': [{'IsPrimary': False, 'Name': 'Trailer'}]},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': 'Ability Metals',
#               'Mfr_ID': 1194,
#               'Mfr_Name': 'ABILITY METALS',
#               'VehicleTypes': [{'IsPrimary': True, 'Name': 'Trailer'}]},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': 'Absolute Concepts',
#               'Mfr_ID': 1195,
#               'Mfr_Name': 'ABSOLUTE CONCEPTS INC.',
#               'VehicleTypes': [{'IsPrimary': True, 'Name': 'Trailer'}]},
#              {'Country': 'CANADA',
#               'Mfr_CommonName': 'Matrixx Specialized Trailers',
#               'Mfr_ID': 1196,
#               'Mfr_Name': '2231545 ONTARIO INC. DBA MATRIXX SPECIALIZED '
#                           'TRAILERS',
#               'VehicleTypes': [{'IsPrimary': True, 'Name': 'Trailer'}]},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': 'Crane Hills Machine & Fabrication',
#               'Mfr_ID': 1198,
#               'Mfr_Name': 'ROYALTY INVESTMENTS, LLC',
#               'VehicleTypes': []},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': 'Trailers',
#               'Mfr_ID': 1199,
#               'Mfr_Name': 'COUNTRY TRAILERS LLC',
#               'VehicleTypes': [{'IsPrimary': False, 'Name': 'Trailer'}]},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': 'Craneworks',
#               'Mfr_ID': 1201,
#               'Mfr_Name': 'CRANEWORKS, INC.',
#               'VehicleTypes': [{'IsPrimary': True, 'Name': 'Trailer'}]},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': 'Crary Agricultural',
#               'Mfr_ID': 1202,
#               'Mfr_Name': 'CRARY AGRICULTURAL SOLUTIONS, LLC',
#               'VehicleTypes': [{'IsPrimary': False, 'Name': 'Trailer'}]},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': 'Crazy Dago',
#               'Mfr_ID': 1203,
#               'Mfr_Name': 'CRAZY DAGO CUSTOMS',
#               'VehicleTypes': [{'IsPrimary': True, 'Name': 'Motorcycle'}]},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': 'Crazy Horse Iron',
#               'Mfr_ID': 1204,
#               'Mfr_Name': 'CRAZY HORSE IRON, LLC',
#               'VehicleTypes': []},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': 'CRC Cemetery',
#               'Mfr_ID': 1205,
#               'Mfr_Name': 'CRC CEMETERY SERVICES INC.',
#               'VehicleTypes': [{'IsPrimary': False, 'Name': 'Trailer'}]},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': 'Create-A-Custom Cycle',
#               'Mfr_ID': 1206,
#               'Mfr_Name': 'CREATE-A-CUSTOM CYCLE LLC',
#               'VehicleTypes': [{'IsPrimary': True, 'Name': 'Motorcycle'}]},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': None,
#               'Mfr_ID': 1207,
#               'Mfr_Name': 'CREATIVE COACHWORKS, INC',
#               'VehicleTypes': [{'IsPrimary': False,
#                                 'Name': 'Multipurpose Passenger Vehicle '
#                                         '(MPV)'}]},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': 'Creative Sports Supply',
#               'Mfr_ID': 1208,
#               'Mfr_Name': 'CREATIVE SPORTS SUPPLY LLC',
#               'VehicleTypes': [{'IsPrimary': True, 'Name': 'Trailer'}]},
#              {'Country': 'UNITED STATES (USA)',
#               'Mfr_CommonName': 'Creep Cycle',
#               'Mfr_ID': 1209,
#               'Mfr_Name': 'CREEP CYCLE WORKS INC.',
#               'VehicleTypes': [{'IsPrimary': True, 'Name': 'Motorcycle'}]}],
#  'SearchCriteria': None}

# %%
# getting creative with our extract function

def extract_vehicle_data(endpoint, search_param=None, format="json" ):
  """Description:
      Ingest data from API endpoint
    Parameters:
      endpoint : API endpoint hosting data
      search_param : string to query endpoint e.g model name - "mercedes
      format : data format for response - Options are json, csv, xml, defaults to json
    Returns:
      JSON data
      """

  params = {"format" : format}

  if search_param is None:
    uri = f"https://vpic.nhtsa.dot.gov/api/vehicles/{endpoint}"
  else:
    #params[endpoint] = search_param
    uri = f"https://vpic.nhtsa.dot.gov/api/vehicles/{endpoint}/{search_param}"


  print(f"Extracting data from {uri}")

  try:
    res = requests.get(uri, params=params)
    data = res.json()
  except Exception as e:
    print(f"Exception {e} while extracting data from {e}")
    data = pd.DataFrame()


  return data

# %%
# Example 1 - get all makes

makes = extract_vehicle_data("getallmakes")
makes
# Out:
# Extracting data from https://vpic.nhtsa.dot.gov/api/vehicles/getallmakes
# {'Count': 11440,
#  'Message': 'Response returned successfully',
#  'SearchCriteria': None,
#  'Results': [{'Make_ID': 12858, 'Make_Name': '#1 ALPINE CUSTOMS'},
#   {'Make_ID': 4877, 'Make_Name': '1/OFF KUSTOMS, LLC'},
#   {'Make_ID': 11257, 'Make_Name': '102 IRONWORKS, INC.'},
#   {'Make_ID': 12255, 'Make_Name': '12832429 CANADA INC.'},
#   {'Make_ID': 13053, 'Make_Name': '137 INDUSTRIES INC.'},
#   {'Make_ID': 6387, 'Make_Name': '17 CREEK ENTERPRISES'},
#   {'Make_ID': 12948, 'Make_Name': '1955 CUSTOM BELAIR'},
#   {'Make_ID': 9172, 'Make_Name': '1M CUSTOM CAR TRANSPORTS, INC.'},
#   {'Make_ID': 6124, 'Make_Name': '1ST CHOICE MANUFACTURING INC'},
#   {'Make_ID': 12972, 'Make_Name': '2 GOLDEN EAGLES'},
#   {'Make_ID': 6488, 'Make_Name': '2-G TRAILER CO LLC'},
#   {'Make_ID': 612, 'Make_Name': '2231545 ONTARIO'},
#   {'Make_ID': 11399, 'Make_Name': '24/7 ONSITE CAMERAS INC'},
#   {'Make_ID': 608, 'Make_Name': '280 TRAILERS'},
#   {'Make_ID': 10123, 'Make_Name': '3 CUSTOM SOLUTIONS'},
#   {'Make_ID': 11253, 'Make_Name': '3 STAR MFG LTD'},
#   {'Make_ID': 8792, 'Make_Name': '3&1 ENTERPRISES, LLC DBA IMPACT TRAILERS'},
#   {'Make_ID': 7388, 'Make_Name': '33 EAST MAINTENANCE INC'},
#   {'Make_ID': 10005, 'Make_Name': '357 GOLF CARTS'},
#   {'Make_ID': 11527, 'Make_Name': '36 FEET LLC'},
#   {'Make_ID': 12488, 'Make_Name': '360 CUSTOM TRAILERS'},
#   {'Make_ID': 9857, 'Make_Name': '3C CATTLE FEEDERS INC.'},
#   {'Make_ID': 675, 'Make_Name': '3D CUSTOM ALUMINUM'},
#   {'Make_ID': 4800, 'Make_Name': '3M DYNAMIC MESSAGE SYSTEMS'},
#   {'Make_ID': 12538, 'Make_Name': '3PLUSCOCO'},
#   {'Make_ID': 674, 'Make_Name': '3T MFG.'},
#   {'Make_ID': 11657, 'Make_Name': '4 BOSS'},
#   {'Make_ID': 8195, 'Make_Name': '4 STAR FABRICATION'},
#   {'Make_ID': 10980, 'Make_Name': '4 W '},
#   {'Make_ID': 12443, 'Make_Name': '4 WIDE'},
#   {'Make_ID': 8175, 'Make_Name': '4 X 4 TRAILERS LTD'},
#   {'Make_ID': 9031, 'Make_Name': '4-8 ENTERPRISES'},
#   {'Make_ID': 5676, 'Make_Name': '4-STAR TRAILERS INC.'},
#   {'Make_ID': 12874, 'Make_Name': '41 SERIES'},
#   {'Make_ID': 10908, 'Make_Name': '4L TRAILERS'},
#   {'Make_ID': 7349, 'Make_Name': '4M FARM & TRAILER SALES'},
#   {'Make_ID': 7374, 'Make_Name': '5 STARR TRAILER COMPANY, INC'},
#   {'Make_ID': 4702, 'Make_Name': '505 FABRICATION'},
#   {'Make_ID': 6521, 'Make_Name': '5280 TRAILERWORKS'},
#   {'Make_ID': 9707, 'Make_Name': '55 GRILLS'},
#   {'Make_ID': 673, 'Make_Name': '58TH STREET CUSTOMS'},
#   {'Make_ID': 10122, 'Make_Name': '5JS WELDING'},
#   {'Make_ID': 10301, 'Make_Name': '5M TRAILERS'},
#   {'Make_ID': 8101, 'Make_Name': '5R RANCH TRAILERS'},
#   {'Make_ID': 8851, 'Make_Name': '6 & 34 TRAILERS & MFG, INC.'},
#   {'Make_ID': 12191, 'Make_Name': '6186433 MB LTD / IRONMEN INDUSTRIES'},
#   {'Make_ID': 12345, 'Make_Name': '643 ENTERPRISE'},
#   {'Make_ID': 12888, 'Make_Name': '7 ENERGY'},
#   {'Make_ID': 10636, 'Make_Name': '7 SEAS TRAILERS'},
#   {'Make_ID': 10653, 'Make_Name': '7 SONS CONSTRUCTION'},
#   {'Make_ID': 11425, 'Make_Name': "702 TRAILER'S & WELDING LLC"},
#   {'Make_ID': 10955, 'Make_Name': '7X OFFROAD'},
#   {'Make_ID': 4991, 'Make_Name': '801 TRAILER MANUFACTURING'},
#   {'Make_ID': 11968, 'Make_Name': '818'},
#   {'Make_ID': 10007, 'Make_Name': '9149-0847 QUEBEC INC.'},
#   {'Make_ID': 632, 'Make_Name': 'A & A MANUFACTURING'},
#   {'Make_ID': 7770, 'Make_Name': 'A & B INDUSTRIES'},
#   {'Make_ID': 8220, 'Make_Name': 'A & D COMPANY'},
#   {'Make_ID': 3832, 'Make_Name': 'A & E FABRICATORS'},
#   {'Make_ID': 609, 'Make_Name': 'A & E TRAILERS'},
#   {'Make_ID': 6665, 'Make_Name': 'A & F TRAILER MFG INC'},
#   {'Make_ID': 5983, 'Make_Name': 'A & H'},
#   {'Make_ID': 9910, 'Make_Name': 'A & K TRAILERS'},
#   {'Make_ID': 11466, 'Make_Name': 'A & L SMOKERS'},
#   {'Make_ID': 11245, 'Make_Name': 'A & L TRAILERS'},
#   {'Make_ID': 645, 'Make_Name': 'A & M FABRICATIONS'},
#   {'Make_ID': 9158, 'Make_Name': 'A & R CUSTOM TRAILERS'},
#   {'Make_ID': 6666, 'Make_Name': 'A & W TRAILOR MANUFACTURE'},
#   {'Make_ID': 5695, 'Make_Name': 'A BAR K TRAILERS'},
#   {'Make_ID': 5266, 'Make_Name': 'A SMITH GT BENTLEY'},
#   {'Make_ID': 9296, 'Make_Name': 'A TEAM TRAILERS, LTD.'},
#   {'Make_ID': 631, 'Make_Name': 'A TO Z AUTO'},
#   {'Make_ID': 10338, 'Make_Name': 'A TO Z METAL WORKS CO.'},
#   {'Make_ID': 4614, 'Make_Name': 'A TRINITY TRAILER'},
#   {'Make_ID': 10216, 'Make_Name': 'A&A STEEL ENTERPRISES LTD.'},
#   {'Make_ID': 10785, 'Make_Name': 'A&D '},
#   {'Make_ID': 13052, 'Make_Name': 'A&M TRAILER LLC'},
#   {'Make_ID': 11770, 'Make_Name': 'A&P WELDING'},
#   {'Make_ID': 11655, 'Make_Name': 'A&R ECONOMY CARGO TRAILERS'},
#   {'Make_ID': 610, 'Make_Name': 'A-1 CUSTOM TRAILER AKA TOW MASTER'},
#   {'Make_ID': 5803, 'Make_Name': 'A-1 HITCH & TRAILER SALES, INC.'},
#   {'Make_ID': 7751, 'Make_Name': 'A-1 TRUCK REPAIR'},
#   {'Make_ID': 611, 'Make_Name': 'A-BAR-D MFG.'},
#   {'Make_ID': 9632, 'Make_Name': 'A-N-S MANUFACTURING, INC.'},
#   {'Make_ID': 3833, 'Make_Name': 'A. B. CHANCE COMPANY'},
#   {'Make_ID': 9135, 'Make_Name': 'A. BERGMAN'},
#   {'Make_ID': 3834, 'Make_Name': 'A.A. TRAILER'},
#   {'Make_ID': 11956, 'Make_Name': 'A.G.A EL AMIGUITO'},
#   {'Make_ID': 628, 'Make_Name': 'A.N. BOWLING'},
#   {'Make_ID': 7414, 'Make_Name': 'A.P.C. MOTOR COMPANY'},
#   {'Make_ID': 7018, 'Make_Name': 'A.P.E, INC'},
#   {'Make_ID': 626, 'Make_Name': 'A.Q. MANUFACTURING'},
#   {'Make_ID': 12745, 'Make_Name': 'A.R. SERVICES'},
#   {'Make_ID': 614, 'Make_Name': 'A.R.M.'},
#   {'Make_ID': 9635, 'Make_Name': 'A.S.C.'},
#   {'Make_ID': 8793, 'Make_Name': 'A.T.M.'},
#   {'Make_ID': 12727, 'Make_Name': 'A.V. TRAILERS L.L.C.'},
#   {'Make_ID': 624, 'Make_Name': 'A1 CYCLES'},
#   {'Make_ID': 11314, 'Make_Name': 'A1 FOOD TRUCK DEPOT LLC'},
#   {'Make_ID': 11534, 'Make_Name': 'A2M2 TRAILERS'},
#   {'Make_ID': 11301, 'Make_Name': 'A2Z'},
#   {'Make_ID': 4708, 'Make_Name': 'AA MUFFLER AND WELDING'},
#   {'Make_ID': 3836, 'Make_Name': 'AA SCREEN SUPPLY'},
#   {'Make_ID': 5696, 'Make_Name': 'AA WELDING'},
#   {'Make_ID': 9785, 'Make_Name': 'AAA MARINE'},
#   {'Make_ID': 9877, 'Make_Name': 'AAA TRAILER SALES LLC'},
#   {'Make_ID': 8834, 'Make_Name': 'AAD WELDING, INC.'},
#   {'Make_ID': 7490, 'Make_Name': 'AAPEX TRAILERS INC'},
#   {'Make_ID': 7514, 'Make_Name': 'AAR WELDING'},
#   {'Make_ID': 6867, 'Make_Name': 'AARON WORLDWIDE MACHINE CO., INC.'},
#   {'Make_ID': 1288, 'Make_Name': 'AAS'},
#   {'Make_ID': 621, 'Make_Name': 'ABASTECEDORA DE TRACTOPARTES Y REFACCIONES'},
#   {'Make_ID': 11919, 'Make_Name': 'ABBA TRAILERS LLC'},
#   {'Make_ID': 3837, 'Make_Name': 'ABC ENTERPRISES'},
#   {'Make_ID': 3838, 'Make_Name': 'ABC MANUFACTURING'},
#   {'Make_ID': 11514, 'Make_Name': 'ABCMFG, INC'},
#   {'Make_ID': 10916, 'Make_Name': 'ABD EQUIPMENT & PARTS LLC'},
#   {'Make_ID': 8037, 'Make_Name': 'ABI'},
#   {'Make_ID': 5984, 'Make_Name': 'ABI CARAVANS LTD'},
#   {'Make_ID': 622, 'Make_Name': 'ABILITY METALS'},
#   {'Make_ID': 4672, 'Make_Name': 'ABLE INDUSTRIES'},
#   {'Make_ID': 11538, 'Make_Name': 'ABS'},
#   {'Make_ID': 623, 'Make_Name': 'ABSOLUTE CONCEPTS'},
#   {'Make_ID': 767, 'Make_Name': 'ABSOLUTE PERFORMANCE'},
#   {'Make_ID': 768, 'Make_Name': 'ABSOLUTE TRAILER SALES'},
#   {'Make_ID': 769, 'Make_Name': 'ABSOLUTELY WILD RANCH'},
#   {'Make_ID': 9395, 'Make_Name': 'ABTEC OF WISCONSIN, INC.'},
#   {'Make_ID': 6141, 'Make_Name': 'ABU'},
#   {'Make_ID': 770, 'Make_Name': 'AC CUSTOMS'},
#   {'Make_ID': 771, 'Make_Name': 'AC PROPULSION'},
#   {'Make_ID': 772, 'Make_Name': 'ACADEMI TRAINING CENTER'},
#   {'Make_ID': 773, 'Make_Name': 'ACC TRAILRITE'},
#   {'Make_ID': 9229, 'Make_Name': 'ACCEL TRAILERS INC.'},
#   {'Make_ID': 9559, 'Make_Name': 'ACCELERATED MEDIA TECHNOLOGIES'},
#   {'Make_ID': 9490, 'Make_Name': 'ACCELERATED SPEED DYNAMICS, INC'},
#   {'Make_ID': 1113, 'Make_Name': 'ACCELERATED TANKS AND TRAILERS'},
#   {'Make_ID': 6484, 'Make_Name': 'ACCU-TEK TRAILER MANUFACTURING, INC.'},
#   {'Make_ID': 8608, 'Make_Name': 'ACCU-WELD TRUCK BODY & TRAILER INC'},
#   {'Make_ID': 6653, 'Make_Name': 'ACCURATE CYCLE ENGINEERING'},
#   {'Make_ID': 774, 'Make_Name': 'ACCUSTOMX'},
#   {'Make_ID': 1518, 'Make_Name': 'ACE'},
#   {'Make_ID': 5700, 'Make_Name': 'ACE CUSTOM TRAILERS'},
#   {'Make_ID': 11813, 'Make_Name': 'ACE METALWORKS LLC'},
#   {'Make_ID': 10091, 'Make_Name': 'ACE MFG'},
#   {'Make_ID': 7360, 'Make_Name': 'ACE MOTORCYCLE'},
#   {'Make_ID': 775, 'Make_Name': 'ACE OF SPADES'},
#   {'Make_ID': 4758, 'Make_Name': 'ACE TRAILERS'},
#   {'Make_ID': 9511, 'Make_Name': 'ACE TRUCK BODY CO.'},
#   {'Make_ID': 11211, 'Make_Name': 'ACELA, INC'},
#   {'Make_ID': 6548, 'Make_Name': 'ACES CHOPPERWORKS'},
#   {'Make_ID': 457, 'Make_Name': 'ACG'},
#   {'Make_ID': 9560, 'Make_Name': 'ACI'},
#   {'Make_ID': 10332, 'Make_Name': 'ACKER-BUILT'},
#   {'Make_ID': 8307, 'Make_Name': 'ACME'},
#   {'Make_ID': 6519, 'Make_Name': 'ACME CRYOGENICS, INC.'},
#   {'Make_ID': 776, 'Make_Name': 'ACME GROUP'},
#   {'Make_ID': 777, 'Make_Name': 'ACME INDUSTRIES'},
#   {'Make_ID': 778, 'Make_Name': 'ACME TRAILER WORKS'},
#   {'Make_ID': 12692, 'Make_Name': 'ACP TRAILERS'},
#   {'Make_ID': 6181, 'Make_Name': 'ACRO TRAILER COMPANY'},
#   {'Make_ID': 779, 'Make_Name': 'ACTION ENTERPRISES & FABRICATION'},
#   {'Make_ID': 780, 'Make_Name': 'ACTION EQUIPMENT'},
#   {'Make_ID': 8729, 'Make_Name': 'ACTION INDUSTRIAL STUDIO'},
#   {'Make_ID': 781, 'Make_Name': 'ACTION SIGNS AND BILLBOARDS'},
#   {'Make_ID': 4799, 'Make_Name': 'ACTION TRAILERS'},
#   {'Make_ID': 6602, 'Make_Name': 'ACTION WELDING & FABRICATION, INC.'},
#   {'Make_ID': 11323, 'Make_Name': 'ACTIVEDOGS'},
#   {'Make_ID': 12238, 'Make_Name': 'ACTIVEV LLC'},
#   {'Make_ID': 782, 'Make_Name': 'ACTIVITY TRAILER'},
#   {'Make_ID': 783, 'Make_Name': 'ACTIVMO AUTO'},
#   {'Make_ID': 475, 'Make_Name': 'ACURA'},
#   {'Make_ID': 5756, 'Make_Name': 'ACV INC'},
#   {'Make_ID': 5670, 'Make_Name': 'ADAM TRAILERS'},
#   {'Make_ID': 8157, 'Make_Name': 'ADAMS EQUIPMENT'},
#   {'Make_ID': 784, 'Make_Name': 'ADAMS MFG'},
#   {'Make_ID': 12127, 'Make_Name': 'ADDAX OVERLAND LLC'},
#   {'Make_ID': 785, 'Make_Name': 'ADDCO'},
#   {'Make_ID': 6479, 'Make_Name': 'ADIRONDACK KABINS, LLC'},
#   {'Make_ID': 5680, 'Make_Name': 'ADIRONDACK KOTTAGES'},
#   {'Make_ID': 4517, 'Make_Name': 'ADIRONDACK WHITE PINE CABINS'},
#   {'Make_ID': 2464, 'Make_Name': 'ADLY'},
#   {'Make_ID': 11141, 'Make_Name': 'ADM MANUFACTURING'},
#   {'Make_ID': 3840, 'Make_Name': 'ADMIRAL DRIVE SYSTEMS'},
#   {'Make_ID': 786, 'Make_Name': 'ADMIRAL TRAILERS'},
#   {'Make_ID': 5806, 'Make_Name': 'ADMIRATION HOMES'},
#   {'Make_ID': 11045, 'Make_Name': 'ADMW'},
#   {'Make_ID': 4792, 'Make_Name': 'ADRENALINE'},
#   {'Make_ID': 787, 'Make_Name': 'ADRIAN HOMES'},
#   {'Make_ID': 11768, 'Make_Name': 'ADS MANUFACTURING'},
#   {'Make_ID': 12653, 'Make_Name': 'ADU 100'},
#   {'Make_ID': 12654, 'Make_Name': 'ADU 200'},
#   {'Make_ID': 792, 'Make_Name': 'ADVANCE ENGINEERED PRODUCTS'},
#   {'Make_ID': 795, 'Make_Name': 'ADVANCE LIFTS'},
#   {'Make_ID': 6294, 'Make_Name': 'ADVANCE MECHANICAL SERVICE'},
#   {'Make_ID': 4667, 'Make_Name': 'ADVANCE METAL FABRICATION AND MACHINE'},
#   {'Make_ID': 796, 'Make_Name': 'ADVANCE PUMP & EQUIPMENT'},
#   {'Make_ID': 11367, 'Make_Name': 'ADVANCED BOAT'},
#   {'Make_ID': 6407, 'Make_Name': 'ADVANCED BOAT TRAILERS, INC.'},
#   {'Make_ID': 7077, 'Make_Name': 'ADVANCED CONTAINMENT SYSTEMS, INC'},
#   {'Make_ID': 797, 'Make_Name': 'ADVANCED CUSTOMS & CONVERSIONS'},
#   {'Make_ID': 8235, 'Make_Name': 'ADVANCED DIRECTIONAL DRILLING SERVICES'},
#   {'Make_ID': 10155, 'Make_Name': 'ADVANCED EV'},
#   {'Make_ID': 8589, 'Make_Name': 'ADVANCED FABRICATION'},
#   {'Make_ID': 6982, 'Make_Name': 'ADVANCED FABRICATORS INC'},
#   {'Make_ID': 11032, 'Make_Name': 'ADVANCED FIELD SERVICES, LLC'},
#   {'Make_ID': 7776,
#    'Make_Name': 'ADVANCED MANUFACTURING & POWER SYSTEMS, INC.'},
#   {'Make_ID': 12000, 'Make_Name': 'ADVANCED METAL PRODUCTS, INC'},
#   {'Make_ID': 8242, 'Make_Name': 'ADVANCED METALCRAFT & CO'},
#   {'Make_ID': 8214, 'Make_Name': 'ADVANCED PORTABLE BUILDINGS & TRAILERS'},
#   {'Make_ID': 8912, 'Make_Name': 'ADVANCED STRIPING EQUIPMENT'},
#   {'Make_ID': 8551, 'Make_Name': 'ADVANCED TRAILER CONCEPTS, INC.'},
#   {'Make_ID': 8789, 'Make_Name': 'ADVANCED TRAILER SERVICE, INC.'},
#   {'Make_ID': 4593, 'Make_Name': 'ADVANCED TRAILER SOLUTIONS'},
#   {'Make_ID': 8083, 'Make_Name': 'ADVANCED TRAILER SYSTEMS'},
#   {'Make_ID': 9132, 'Make_Name': 'ADVANCED TRANSPORT TECHNOLOGIES INC.'},
#   {'Make_ID': 3889, 'Make_Name': 'ADVANCED WELDING AND MANUFACTURING'},
#   {'Make_ID': 806, 'Make_Name': 'ADVANTAGE CUSTOMS'},
#   {'Make_ID': 4604, 'Make_Name': 'ADVANTAGE TERRAFAB, LLC'},
#   {'Make_ID': 9662, 'Make_Name': 'ADVANTAGE TRAILERS'},
#   {'Make_ID': 12227, 'Make_Name': 'ADVENTURE'},
#   {'Make_ID': 12250, 'Make_Name': 'ADVENTURE COAST'},
#   {'Make_ID': 12252, 'Make_Name': 'ADVENTURE COAST, LLC'},
#   {'Make_ID': 7546, 'Make_Name': 'ADVENTURE SPORTS PRODUCTS, INC'},
#   {'Make_ID': 3890, 'Make_Name': 'ADVENTURE TRAILERS'},
#   {'Make_ID': 4798, 'Make_Name': 'AEC ENTERPRISES'},
#   {'Make_ID': 807, 'Make_Name': 'AEP NORTH AMERICA'},
#   {'Make_ID': 8591, 'Make_Name': 'AERO'},
#   {'Make_ID': 10287, 'Make_Name': 'AERO BUILD LLC'},
#   {'Make_ID': 7793, 'Make_Name': 'AERO FIBERGLASS COMPANY'},
#   {'Make_ID': 6572, 'Make_Name': 'AERO FLITE'},
#   {'Make_ID': 11431, 'Make_Name': 'AERO MOTO'},
#   {'Make_ID': 4807, 'Make_Name': 'AERO MOTORS'},
#   {'Make_ID': 8904, 'Make_Name': 'AERO MOTORSPORTS'},
#   {'Make_ID': 12773, 'Make_Name': 'AERO PRECISION METAL WORKS LLC'},
#   {'Make_ID': 5267, 'Make_Name': 'AERO TEARDROPS, LLC'},
#   {'Make_ID': 5430, 'Make_Name': 'AERO TRAILERS'},
#   {'Make_ID': 808, 'Make_Name': 'AEROBILT MANUFACTURING'},
#   {'Make_ID': 7373, 'Make_Name': 'AEROGLAS'},
#   {'Make_ID': 7884, 'Make_Name': 'AEROPUP TRAILERS LLC'},
#   {'Make_ID': 8899, 'Make_Name': 'AEROSWINT TRAILERS'},
#   {'Make_ID': 10731, 'Make_Name': 'AEROTECH COATINGS LLC'},
#   {'Make_ID': 5924, 'Make_Name': 'AEROTEK'},
#   {'Make_ID': 1231, 'Make_Name': 'AEROVAULT'},
#   {'Make_ID': 1233,
#    'Make_Name': 'AFAB PETROLEUM EQUIPMENT & STEEL FABRICATION'},
#   {'Make_ID': 1235, 'Make_Name': 'AFC COMPANY'},
#   {'Make_ID': 11946, 'Make_Name': 'AFCR'},
#   {'Make_ID': 1237, 'Make_Name': 'AFFORDABLE ALUMINUM'},
#   {'Make_ID': 10240, 'Make_Name': 'AFFORDABLE TRAILERS'},
#   {'Make_ID': 1238, 'Make_Name': 'AFTER HOURS'},
#   {'Make_ID': 7059, 'Make_Name': 'AFTER-MARKET SPECIALTIES'},
#   {'Make_ID': 4855, 'Make_Name': 'AG DRYER SERVICES INC.'},
#   {'Make_ID': 7377, 'Make_Name': 'AG INDUSTRIAL, INC'},
#   {'Make_ID': 4797, 'Make_Name': 'AG SHIELD MANUFACTURING'},
#   {'Make_ID': 1015, 'Make_Name': 'AG SPRAY EQUIPMENT'},
#   {'Make_ID': 6078, 'Make_Name': 'AG SPRAY EQUIPMENT,INC.'},
#   {'Make_ID': 4609, 'Make_Name': 'AG WORKS INTERNATIONAL'},
#   {'Make_ID': 1241, 'Make_Name': 'AG-QUIP, INC.'},
#   {'Make_ID': 6080, 'Make_Name': 'AG. BELT TRAILER'},
#   {'Make_ID': 7944, 'Make_Name': 'AGA GAS CENTRAL, INC'},
#   {'Make_ID': 10491, 'Make_Name': 'AGAMS, CO. LTD'},
#   {'Make_ID': 11226, 'Make_Name': 'AGAZU'},
#   {'Make_ID': 1240, 'Make_Name': 'AGB'},
#   {'Make_ID': 11715, 'Make_Name': "AGC LSV'S"},
#   {'Make_ID': 6079, 'Make_Name': 'AGRI-DRAIN CORP'},
#   {'Make_ID': 1243, 'Make_Name': 'AGRIFLEET LEASING CORPORATION'},
#   {'Make_ID': 1244, 'Make_Name': "AGUILAR'S WELDING, INC."},
#   {'Make_ID': 8680, 'Make_Name': 'AGVANTAGE MANUFACTURING CORP.'},
#   {'Make_ID': 11788, 'Make_Name': 'AHGO FOOD TRAILERS'},
#   {'Make_ID': 3891, 'Make_Name': 'AHOY! HOUSEBOATS AND FISHHOUSES'},
#   {'Make_ID': 11628, 'Make_Name': 'AI TRAILERS'},
#   {'Make_ID': 12581, 'Make_Name': 'AIM TRAILERS'},
#   {'Make_ID': 11428, 'Make_Name': 'AIMHIGH'},
#   {'Make_ID': 1247, 'Make_Name': 'AINLEY KENNELS & FABRICATION, INC.'},
#   {'Make_ID': 11286, 'Make_Name': 'AIR EASY LLC DBA AVENTURA-X'},
#   {'Make_ID': 3878, 'Make_Name': 'AIR RESPONDER'},
#   {'Make_ID': 11754, 'Make_Name': 'AIR-FLO'},
#   {'Make_ID': 12053, 'Make_Name': 'AIR-TOW TRAILERS'},
#   {'Make_ID': 1249, 'Make_Name': 'AIRBAGGED TRAILERS, INC.'},
#   {'Make_ID': 9482, 'Make_Name': 'AIRBURNERS'},
#   {'Make_ID': 12700, 'Make_Name': 'AIRLITE TRAILERS, LLC'},
#   {'Make_ID': 10805, 'Make_Name': 'AIRSTREAM'},
#   {'Make_ID': 2029, 'Make_Name': 'AIRSTREAM INC.'},
#   {'Make_ID': 1253, 'Make_Name': 'AIRTECH TOOLS'},
#   {'Make_ID': 1286, 'Make_Name': 'AIRTRONICS METAL PRODUCTS'},
#   {'Make_ID': 11279, 'Make_Name': 'AIRY'},
#   {'Make_ID': 11705, 'Make_Name': 'AJAX TOCCO MAGNETHERMIC CORPORATION'},
#   {'Make_ID': 7972, 'Make_Name': 'AJAX TOOLS, INC.'},
#   {'Make_ID': 7168, 'Make_Name': 'AJAX TRAILERS, INC'},
#   {'Make_ID': 9619, 'Make_Name': 'AJR INC.'},
#   {'Make_ID': 11288, 'Make_Name': 'AKY'},
#   {'Make_ID': 1487, 'Make_Name': "AL'S MOTORSICKLE SHOP INC."},
#   {'Make_ID': 7883, 'Make_Name': 'AL-JON, INC.'},
#   {'Make_ID': 1287, 'Make_Name': 'ALAMEDA TRAILER SALES'},
#   {'Make_ID': 1289, 'Make_Name': 'ALAN RITCHEY, INC.'},
#   {'Make_ID': 1783, 'Make_Name': 'ALASKA EXTREME TRAILER'},
#   {'Make_ID': 7189, 'Make_Name': 'ALASKA FRONTIER FABRICATION LLC'},
#   {'Make_ID': 11690, 'Make_Name': 'ALASKA SEA KING'},
#   {'Make_ID': 1291, 'Make_Name': 'ALBERT BÖCKER GMBH & CO. KG'},
#   {'Make_ID': 6133, 'Make_Name': 'ALBERT LEA'},
#   {'Make_ID': 1293, 'Make_Name': 'ALBRIGHT BIKES'},
#   {'Make_ID': 4793, 'Make_Name': 'ALC MANUFACTURING'},
#   {'Make_ID': 1294, 'Make_Name': 'ALCAN TRAILERS, LLC'},
#   {'Make_ID': 7161, 'Make_Name': 'ALCAN TRAVELER, INC'},
#   {'Make_ID': 12984, 'Make_Name': 'ALCANTAR CUSTOM TRAILERS'},
#   {'Make_ID': 12433, 'Make_Name': 'ALCC'},
#   {'Make_ID': 1296, 'Make_Name': 'ALCOM LLC'},
#   {'Make_ID': 12432, 'Make_Name': 'ALCT'},
#   {'Make_ID': 5321, 'Make_Name': 'ALDURA'},
#   {'Make_ID': 12944, 'Make_Name': 'ALEMAN'},
#   {'Make_ID': 1299, 'Make_Name': 'ALEPH GROUP, INC.'},
#   {'Make_ID': 6710, 'Make_Name': 'ALEWINE MOTORS, INC.'},
#   {'Make_ID': 7502, 'Make_Name': 'ALEXANDER DENNIS LIMITED'},
#   {'Make_ID': 4588,
#    'Make_Name': "ALEXANDER'S MACHINE AND MAINTENANCE SERVICE COMPANY"},
#   {'Make_ID': 10178, 'Make_Name': 'ALFA CARGO LLC'},
#   {'Make_ID': 493, 'Make_Name': 'ALFA ROMEO'},
#   {'Make_ID': 1306, 'Make_Name': 'ALFRED INDUSTRIES'},
#   {'Make_ID': 9672, 'Make_Name': 'ALIEN'},
#   {'Make_ID': 12542, 'Make_Name': 'ALIEN ATV'},
#   {'Make_ID': 4671, 'Make_Name': 'ALIEN ENGINEERED PRODUCTS'},
#   {'Make_ID': 5441, 'Make_Name': 'ALINER'},
#   {'Make_ID': 8316, 'Make_Name': 'ALISO TRAILER MFG. INC.'},
#   {'Make_ID': 6493, 'Make_Name': 'ALKANE'},
#   {'Make_ID': 12818, 'Make_Name': 'ALKO'},
#   {'Make_ID': 8304, 'Make_Name': 'ALKOTA CLEANING SYSTEMS, INC.'},
#   {'Make_ID': 1308, 'Make_Name': 'ALL ABOUT TRAILERS'},
#   {'Make_ID': 12415, 'Make_Name': 'ALL ALUMINUM STRUCTURE'},
#   {'Make_ID': 7598, 'Make_Name': 'ALL AMERICAN BIG TWIN'},
#   {'Make_ID': 1310, 'Make_Name': 'ALL AMERICAN CHOPPERS CO.'},
#   {'Make_ID': 10202, 'Make_Name': 'ALL AMERICAN MANUFACTURING LLC'},
#   {'Make_ID': 1312, 'Make_Name': 'ALL AMERICAN MANUFACTURING, INC.'},
#   {'Make_ID': 1391, 'Make_Name': 'ALL AMERICAN TRAILER MANUFACTURERS'},
#   {'Make_ID': 11480, 'Make_Name': 'ALL AMERICAN UTILITIES LLC'},
#   {'Make_ID': 1436, 'Make_Name': 'ALL AROUND TRAILERS'},
#   {'Make_ID': 1437, 'Make_Name': 'ALL BOAT MANUFACTURING'},
#   {'Make_ID': 10775, 'Make_Name': 'ALL CUSTOM '},
#   {'Make_ID': 1438, 'Make_Name': 'ALL CUSTOM FABRICATIONS'},
#   {'Make_ID': 1439, 'Make_Name': 'ALL DAY LAWN'},
#   {'Make_ID': 1440, 'Make_Name': 'ALL FAB TRAILERS'},
#   {'Make_ID': 12147, 'Make_Name': 'ALL GOOD EQUIPMENT'},
#   {'Make_ID': 6499, 'Make_Name': 'ALL IN ONE CUSTOM FABRICATION & DESIGN'},
#   {'Make_ID': 3893, 'Make_Name': 'ALL MARINE TRAILERS'},
#   {'Make_ID': 12452, 'Make_Name': 'ALL OUT CUSTOM TRAILERS & FABRICATION'},
#   {'Make_ID': 1441, 'Make_Name': 'ALL PHASE TRAILER AND EQUIPMENT'},
#   {'Make_ID': 4790, 'Make_Name': 'ALL PRO CYCLES'},
#   {'Make_ID': 1443, 'Make_Name': 'ALL RIGHT STEEL, LLC.'},
#   {'Make_ID': 3894, 'Make_Name': 'ALL SEASONS MANUFACTURING'},
#   {'Make_ID': 1445, 'Make_Name': 'ALL SOUTH EQUIPMENT CO. INC.'},
#   {'Make_ID': 1446, 'Make_Name': 'ALL STAR CARTS & VEHICLES, INC.'},
#   {'Make_ID': 6561, 'Make_Name': 'ALL STAR SOLUTIONS'},
#   {'Make_ID': 1447, 'Make_Name': 'ALL STAR TRAILERS'},
#   {'Make_ID': 11204, 'Make_Name': 'ALL STAR TRAILERS FABRICATION'},
#   {'Make_ID': 11769, 'Make_Name': 'ALL STATE'},
#   {'Make_ID': 1449, 'Make_Name': 'ALL STEEL TRAILER, LLC'},
#   {'Make_ID': 9126, 'Make_Name': 'ALL WHEEL DRIVE EQUIPMENT MFG., INC.'},
#   {'Make_ID': 11845, 'Make_Name': 'ALL WORLD TRAILERS LLC'},
#   {'Make_ID': 8900, 'Make_Name': 'ALL-IN-ONE PRODUCTS'},
#   {'Make_ID': 11792, 'Make_Name': 'ALLARD MOTOR WORKS'},
#   {'Make_ID': 12262, 'Make_Name': 'ALLBETTER'},
#   {'Make_ID': 8160, 'Make_Name': 'ALLCO TRAILER MANUFACTURING'},
#   {'Make_ID': 12315, 'Make_Name': 'ALLEGHENY TRAILERS'},
#   {'Make_ID': 7932, 'Make_Name': 'ALLEN BOAT COMPANY'},
#   {'Make_ID': 1451, 'Make_Name': 'ALLEN FABRICATORS INC.'},
#   {'Make_ID': 10703, 'Make_Name': "ALLEN'S"},
#   {'Make_ID': 6872, 'Make_Name': "ALLEN'S MFG INC."},
#   {'Make_ID': 1452, 'Make_Name': 'ALLENTOWN SHOTCRETE TECHNOLOGY, INC.'},
#   {'Make_ID': 1462, 'Make_Name': 'ALLEY RAT CUSTOM CYCLES LLC'},
#   {'Make_ID': 1467, 'Make_Name': 'ALLEYKAT KUSTOMS OF ARIZONA'},
#   {'Make_ID': 7097, 'Make_Name': 'ALLIANCE NORTH AMERICA, INC'},
#   {'Make_ID': 10304, 'Make_Name': 'ALLIANCE RV'},
#   {'Make_ID': 1470, 'Make_Name': 'ALLIANZ SWEEPER COMPANY'},
#   {'Make_ID': 7785, 'Make_Name': 'ALLIED MACHINE INC'},
#   {'Make_ID': 1473, 'Make_Name': 'ALLIED MANUFACTURING, INC.'},
#   {'Make_ID': 10055, 'Make_Name': 'ALLIED TRAILER WORKS (ATW)'},
#   {'Make_ID': 7694, 'Make_Name': 'ALLIED WELDING SERVICES'},
#   {'Make_ID': 6713, 'Make_Name': 'ALLISON DUMP BODIES & TRAILERS'},
#   {'Make_ID': 9888, 'Make_Name': 'ALLMAND BROS, INC.'},
#   {'Make_ID': 5268, 'Make_Name': 'ALLMAND BROTHERS'},
#   {'Make_ID': 9770, 'Make_Name': 'ALLOUTHUNTING'},
#   {'Make_ID': 5399, 'Make_Name': 'ALLOY'},
#   {'Make_ID': 7781, 'Make_Name': 'ALLOY CUSTOM PRODUCTS'},
#   {'Make_ID': 7353, 'Make_Name': 'ALLOY CUSTOM VACUUM PRODUCTS INC'},
#   {'Make_ID': 10423, 'Make_Name': 'ALLROAD ORV'},
#   {'Make_ID': 8655, 'Make_Name': 'ALLSTATES PRODUCTION EQUIPMENT COMPANY'},
#   {'Make_ID': 10938, 'Make_Name': 'ALLURE TRAILERS'},
#   {'Make_ID': 9104, 'Make_Name': 'ALLVAN CORPORATION'},
#   {'Make_ID': 6812, 'Make_Name': 'ALMAR MANUFACTURING'},
#   {'Make_ID': 7748, 'Make_Name': 'ALMAX HOLDING LIMITED'},
#   {'Make_ID': 9060, 'Make_Name': 'ALMIGHTY TRAILERS LLC'},
#   {'Make_ID': 11725, 'Make_Name': 'ALPACAMPER'},
#   {'Make_ID': 10080, 'Make_Name': 'ALPHA BOATS UNLIMITED'},
#   {'Make_ID': 11906, 'Make_Name': 'ALPHA CARGO TRAILERS LLC'},
#   {'Make_ID': 1480, 'Make_Name': 'ALPHA PRODUCTS INTERNATIONAL'},
#   {'Make_ID': 8972, 'Make_Name': 'ALPHA TANK BUILDERS'},
#   {'Make_ID': 10369, 'Make_Name': 'ALPHAHD TRAILERS'},
#   {'Make_ID': 11081, 'Make_Name': 'ALPINE'},
#   {'Make_ID': 8911, 'Make_Name': 'ALPINE INDUSTRIAL, LLC'},
#   {'Make_ID': 9841, 'Make_Name': 'ALPINE TRAILERS, LLC'},
#   {'Make_ID': 8030, 'Make_Name': 'ALPINE WELDING & FABRICATION INC'},
#   {'Make_ID': 1492, 'Make_Name': 'ALSALOR CORP.'},
#   {'Make_ID': 5361, 'Make_Name': 'ALTA'},
#   {'Make_ID': 6813, 'Make_Name': 'ALTAMONT TECHNOLOGIES, INC'},
#   {'Make_ID': 541, 'Make_Name': 'ALTEC'},
#   {'Make_ID': 1494, 'Make_Name': 'ALTEC ENVIRONMENTAL PRODUCTS'},
#   {'Make_ID': 4925, 'Make_Name': 'ALTEC INDUSTRIES, INC.'},
#   {'Make_ID': 8579, 'Make_Name': 'ALTITUDE TEARDROP'},
#   {'Make_ID': 9221, 'Make_Name': 'ALUM-A-FAB INC.'},
#   {'Make_ID': 1508, 'Make_Name': 'ALUM-LINE, INC.'},
#   {'Make_ID': 6142, 'Make_Name': 'ALUMA'},
#   {'Make_ID': 4904, 'Make_Name': 'ALUMA PRO TRAILERS, LLC.'},
#   {'Make_ID': 1495, 'Make_Name': 'ALUMA TOWER COMPANY'},
#   {'Make_ID': 1497, 'Make_Name': 'ALUMACAR'},
#   {'Make_ID': 9216, 'Make_Name': 'ALUMAICE'},
#   {'Make_ID': 9719, 'Make_Name': 'ALUMATECH TRAILERS'},
#   {'Make_ID': 7214, 'Make_Name': 'ALUMATREK'},
#   {'Make_ID': 12955, 'Make_Name': 'ALUMATREK (ALUMATREK TRAILER INC)'},
#   {'Make_ID': 7736, 'Make_Name': 'ALUMAX TRAILERS'},
#   {'Make_ID': 10650, 'Make_Name': 'ALUMI TECH'},
#   {'Make_ID': 13029, 'Make_Name': 'ALUMINA TRAILERS'},
#   {'Make_ID': 1503, 'Make_Name': 'ALUMINA, INC.'},
#   {'Make_ID': 8471, 'Make_Name': 'ALUMINATOR TRAILERS LLC'},
#   {'Make_ID': 3915, 'Make_Name': 'ALUMINEX FABRICATION'},
#   {'Make_ID': 6467, 'Make_Name': 'ALUMINUM CARGO TRAILERS INC'},
#   {'Make_ID': 9044, 'Make_Name': 'ALUMINUM MODEL'},
#   {'Make_ID': 1504, 'Make_Name': 'ALUMINUM TRAILER CO.'},
#   {'Make_ID': 1506, 'Make_Name': 'ALUMINUM TRAILERS, INC.'},
#   {'Make_ID': 7816, 'Make_Name': 'ALUMINX'},
#   {'Make_ID': 4787, 'Make_Name': 'ALUMITUFF MANUFACTURING'},
#   {'Make_ID': 11838, 'Make_Name': 'ALUMMIKON TRAILERS'},
#   {'Make_ID': 7154, 'Make_Name': 'ALVAREZ'},
#   {'Make_ID': 9639, 'Make_Name': 'ALVEY WELDING LLC'},
#   {'Make_ID': 11186, 'Make_Name': 'ALWAYS READY CART CARE LLC'},
#   {'Make_ID': 606, 'Make_Name': 'AM GENERAL'},
#   {'Make_ID': 11311, 'Make_Name': 'AM MACHINERY INC.'},
#   {'Make_ID': 8363, 'Make_Name': 'AMACSA'},
#   {'Make_ID': 8665, 'Make_Name': 'AMARON TRAILERS'},
#   {'Make_ID': 3916, 'Make_Name': 'AMAZE-N-TOW'},
#   {'Make_ID': 1509, 'Make_Name': 'AMAZE-N-TOW, LLC.'},
#   {'Make_ID': 9474, 'Make_Name': 'AMAZING TRAILERS'},
#   {'Make_ID': 11498, 'Make_Name': 'AMBER WAVES INC.'},
#   {'Make_ID': 11732, 'Make_Name': 'AMBERS'},
#   {'Make_ID': 12366, 'Make_Name': 'AMBUSH OUTDOOR PRODUCTS'},
#   {'Make_ID': 10056, 'Make_Name': 'AMC'},
#   {'Make_ID': 10129, 'Make_Name': 'AMC APARATOS MECANICOS DE CALIDAD'},
#   {'Make_ID': 4709, 'Make_Name': 'AMD'},
#   {'Make_ID': 1512, 'Make_Name': 'AMELIT, INC.'},
#   {'Make_ID': 6650, 'Make_Name': 'AMEN CHASSIS WORKS'},
#   {'Make_ID': 1514, 'Make_Name': 'AMERATRAIL'},
#   {'Make_ID': 7679, 'Make_Name': 'AMERI-CAMP'},
#   {'Make_ID': 7032, 'Make_Name': 'AMERI-CAN ENGINEERING, INC.'},
#   {'Make_ID': 830, 'Make_Name': 'AMERI-CARTS'},
#   {'Make_ID': 11377, 'Make_Name': 'AMERICA EV'},
#   {'Make_ID': 6071, 'Make_Name': "AMERICA'S BEST CARGO"},
#   {'Make_ID': 1517, 'Make_Name': 'AMERICAN AIRBOAT CORPORATION'},
#   {'Make_ID': 3917, 'Make_Name': 'AMERICAN AIRPORT SUPPORT & RESCUE SYSTEMS'},
#   {'Make_ID': 9484, 'Make_Name': 'AMERICAN AUGERS'},
#   {'Make_ID': 4673, 'Make_Name': 'AMERICAN BEST CORPORATION'},
#   {'Make_ID': 5985, 'Make_Name': 'AMERICAN BOS CORP'},
#   {'Make_ID': 10223, 'Make_Name': 'AMERICAN CARTS'},
#   {'Make_ID': 1633, 'Make_Name': 'AMERICAN CLASSIC MOTORS INC.'},
#   {'Make_ID': 9631,
#    'Make_Name': 'AMERICAN CONTROL AND ENGINEERING SERVICE, INC.'},
#   {'Make_ID': 1634, 'Make_Name': 'AMERICAN CRAFTED TRAILERS, INC.'},
#   {'Make_ID': 3919, 'Make_Name': 'AMERICAN CUSTOM COACH'},
#   {'Make_ID': 1635, 'Make_Name': 'AMERICAN CUSTOM GOLF CARS, INC.'},
#   {'Make_ID': 12607, 'Make_Name': 'AMERICAN CUSTOM TRAILERS'},
#   {'Make_ID': 6680, 'Make_Name': 'AMERICAN DOZER INC.'},
#   {'Make_ID': 8012, 'Make_Name': 'AMERICAN EAGLE TRAILERS INC.'},
#   {'Make_ID': 1638, 'Make_Name': 'AMERICAN EAGLE TRAILERS, INC.'},
#   {'Make_ID': 1639, 'Make_Name': 'AMERICAN ELECTRIC VEHICLE COMPANY, LLC'},
#   {'Make_ID': 7361, 'Make_Name': 'AMERICAN ELECTRONIC SIGN CO'},
#   {'Make_ID': 6481, 'Make_Name': 'AMERICAN FARRIER SYSTEMS LLC'},
#   {'Make_ID': 3920, 'Make_Name': 'AMERICAN HAULER'},
#   {'Make_ID': 7526, 'Make_Name': 'AMERICAN HAULER INC.'},
#   {'Make_ID': 8498, 'Make_Name': 'AMERICAN HAWG CHOPPERS INC'},
#   {'Make_ID': 8131, 'Make_Name': 'AMERICAN HOMESTAR CORPORATION'},
#   {'Make_ID': 1644, 'Make_Name': 'AMERICAN HOTROD MOTORCYCLES'},
#   {'Make_ID': 12346, 'Make_Name': 'AMERICAN INDUSTRIAL MANUFACTURING'},
#   {'Make_ID': 11929, 'Make_Name': 'AMERICAN INTEGRATED SECURITY GROUP'},
#   {'Make_ID': 4743, 'Make_Name': 'AMERICAN IRONHORSE'},
#   {'Make_ID': 1649, 'Make_Name': 'AMERICAN IRONHORSE MOTORCYCLES'},
#   {'Make_ID': 1978, 'Make_Name': 'AMERICAN KULTURE CYCLES'},
#   {'Make_ID': 1976, 'Make_Name': 'AMERICAN KULTURE ROD AND CYCLE SHOPPE'},
#   {'Make_ID': 1979, 'Make_Name': 'AMERICAN LAFRANCE'},
#   {'Make_ID': 10695, 'Make_Name': 'AMERICAN LANDMASTER'},
#   {'Make_ID': 10085, 'Make_Name': 'AMERICAN LIFAN'},
#   {'Make_ID': 683, 'Make_Name': 'AMERICAN MADE'},
#   {'Make_ID': 11392, 'Make_Name': 'AMERICAN MADE CHASSIS'},
#   {'Make_ID': 684, 'Make_Name': 'AMERICAN MANUFACTURING OPERATIONS'},
#   {'Make_ID': 8586, 'Make_Name': 'AMERICAN MANUFACTURING OPERATIONS, INC.'},
#   {'Make_ID': 685, 'Make_Name': 'AMERICAN MANUFACTURING SUPPORT'},
#   {'Make_ID': 687, 'Make_Name': 'AMERICAN METAL FABRICATION'},
#   {'Make_ID': 9211, 'Make_Name': 'AMERICAN MOBILE VENDING'},
#   {'Make_ID': 689, 'Make_Name': 'AMERICAN MOTORCYCLE CORPORATION'},
#   {'Make_ID': 1124, 'Make_Name': 'AMERICAN MOTORS'},
#   {'Make_ID': 10577, 'Make_Name': 'AMERICAN NOMAD MANUFACTURING'},
#   {'Make_ID': 710, 'Make_Name': 'AMERICAN PERFORMANCE TECHNOLOGIES'},
#   {'Make_ID': 711, 'Make_Name': 'AMERICAN PISTON'},
#   {'Make_ID': 9522, 'Make_Name': 'AMERICAN PNEUMATIC TOOLS'},
#   {'Make_ID': 7191, 'Make_Name': 'AMERICAN PRIDE'},
#   {'Make_ID': 11452, 'Make_Name': 'AMERICAN PRIDE TRAILERS'},
#   {'Make_ID': 715, 'Make_Name': 'AMERICAN PRODUCTS'},
#   {'Make_ID': 11064, 'Make_Name': 'AMERICAN Q-TEC'},
#   {'Make_ID': 6684, 'Make_Name': 'AMERICAN QUANTUM CYCLES'},
#   {'Make_ID': 718, 'Make_Name': 'AMERICAN RECREATIONAL VEHICLES'},
#   {'Make_ID': 9508, 'Make_Name': 'AMERICAN ROAD TRAILERS'},
#   {'Make_ID': 719, 'Make_Name': 'AMERICAN SCOOTER MANUFACTURING'},
#   {'Make_ID': 6194, 'Make_Name': 'AMERICAN SKIER'},
#   {'Make_ID': 720, 'Make_Name': 'AMERICAN SPORT TRAILER'},
#   {'Make_ID': 722, 'Make_Name': 'AMERICAN SPORTWORKS'},
#   {'Make_ID': 1725, 'Make_Name': 'AMERICAN SPRAY TECHNOLOGIES'},
#   {'Make_ID': 727, 'Make_Name': 'AMERICAN STAR METAL FABRICATION'},
#   {'Make_ID': 728, 'Make_Name': 'AMERICAN STEEL FABRICATORS'},
#   {'Make_ID': 730, 'Make_Name': 'AMERICAN STEEL HORSE CYCLES'},
#   {'Make_ID': 3923, 'Make_Name': 'AMERICAN STEEL V-TWIN'},
#   {'Make_ID': 731, 'Make_Name': 'AMERICAN SUPER CYCLE'},
#   {'Make_ID': 10992, 'Make_Name': 'AMERICAN SUPERSTAR '},
#   {'Make_ID': 740, 'Make_Name': 'AMERICAN SURPLUS & MFG'},
#   {'Make_ID': 10718, 'Make_Name': 'AMERICAN TANK'},
#   {'Make_ID': 751, 'Make_Name': 'AMERICAN TEARDROP'},
#   {'Make_ID': 7254, 'Make_Name': 'AMERICAN THUNDER TRYKE'},
#   {'Make_ID': 6135, 'Make_Name': 'AMERICAN TOTE'},
#   {'Make_ID': 7095, 'Make_Name': 'AMERICAN TRAILER AND MANUFACTURING LLC.'},
#   {'Make_ID': 754, 'Make_Name': 'AMERICAN TRAILER BUILDERS'},
#   {'Make_ID': 8969, 'Make_Name': 'AMERICAN TRAILER COMPANY'},
#   {'Make_ID': 7878, 'Make_Name': 'AMERICAN TRAILER MANUFACTURING COMPANY'},
#   {'Make_ID': 9607, 'Make_Name': 'AMERICAN TRAILER MFG'},
#   {'Make_ID': 7486, 'Make_Name': 'AMERICAN TRAILER MFG. CO'},
#   {'Make_ID': 6610, 'Make_Name': 'AMERICAN TRAILER SYSTEMS'},
#   {'Make_ID': 3924, 'Make_Name': 'AMERICAN TRAILERS'},
#   {'Make_ID': 7270, 'Make_Name': 'AMERICAN TRAILERS CO'},
#   {'Make_ID': 9122, 'Make_Name': 'AMERICAN TRAVEL SYSTEMS, INC.'},
#   {'Make_ID': 810, 'Make_Name': 'AMERICAN TRUCK & TRAILER BODY'},
#   {'Make_ID': 8853, 'Make_Name': 'AMERICAN TRUCK COMPANY'},
#   {'Make_ID': 10473, 'Make_Name': 'AMERICAN VACUUM'},
#   {'Make_ID': 9748, 'Make_Name': 'AMERICAN VAN'},
#   {'Make_ID': 10376, 'Make_Name': 'AMERICAN VINTAGE MOTORCYCLE'},
#   {'Make_ID': 6757, 'Make_Name': 'AMERICAN WARRIOR MOTORCYCLES'},
#   {'Make_ID': 4782, 'Make_Name': 'AMERICAN WASH COMPANY'},
#   {'Make_ID': 7674, 'Make_Name': 'AMERICAN WELDING & MACHINE CO'},
#   {'Make_ID': 3925, 'Make_Name': 'AMERICAN WELDING SERVICE'},
#   {'Make_ID': 9621, 'Make_Name': 'AMERICAN WOOD SPLITTERS, INC.'},
#   {'Make_ID': 5632, 'Make_Name': 'AMERICANA'},
#   {'Make_ID': 812, 'Make_Name': 'AMERICANA CHOPPER'},
#   {'Make_ID': 3935, 'Make_Name': 'AMERIFAB INDUSTRIES'},
#   {'Make_ID': 7443, 'Make_Name': 'AMERIMAX'},
#   {'Make_ID': 7289, 'Make_Name': 'AMERIQUIP'},
#   {'Make_ID': 6759, 'Make_Name': 'AMERITECH CORPORATION'},
#   {'Make_ID': 9934, 'Make_Name': 'AMERITRAIL, INC.'},
#   {'Make_ID': 5986, 'Make_Name': 'AMFAB'},
#   {'Make_ID': 10018, 'Make_Name': 'AMIGO MOTORS'},
#   {'Make_ID': 8924, 'Make_Name': 'AMKO SERVICE COMPANY'},
#   {'Make_ID': 3936, 'Make_Name': 'AMP CUSTOMS'},
#   {'Make_ID': 11752, 'Make_Name': 'AMP MARINE LLC'},
#   {'Make_ID': 892, 'Make_Name': 'AMP MOTOR VEHICLES'},
#   {'Make_ID': 10957, 'Make_Name': 'AMP TRAILERS MFG.'},
#   {'Make_ID': 9072, 'Make_Name': "AMP'D UP TRAILERS"},
#   {'Make_ID': 8261, 'Make_Name': 'AMPERE'},
#   {'Make_ID': 6081, 'Make_Name': 'AMPHI-RANGER'},
#   {'Make_ID': 8906, 'Make_Name': 'AMPHIBIAN BOAT TRAILERS, INC.'},
#   {'Make_ID': 9439, 'Make_Name': 'AMRAD PRODUCTS AND SUPPLY COMPANY, INC.'},
#   {'Make_ID': 6193, 'Make_Name': 'AMS'},
#   {'Make_ID': 822, 'Make_Name': 'AMS GLOBAL'},
#   {'Make_ID': 10184, 'Make_Name': 'AMW'},
#   {'Make_ID': 10241, 'Make_Name': 'ANACONDA'},
#   {'Make_ID': 5699, 'Make_Name': 'ANAHEIM WELDING & FABRICATION'},
#   {'Make_ID': 12113, 'Make_Name': 'ANAMNESIS CORPORATION'},
#   {'Make_ID': 8606, 'Make_Name': 'ANARCHY MOTORCYCLE COMPANY'},
#   {'Make_ID': 11624, 'Make_Name': 'ANCHI'},
#   {'Make_ID': 824, 'Make_Name': 'ANDERSON CUSTOM IRON WORKS'},
#   {'Make_ID': 825, 'Make_Name': 'ANDERSON INDUSTRIES'},
#   {'Make_ID': 826, 'Make_Name': 'ANDERSON MFG.'},
#   {'Make_ID': 6082, 'Make_Name': 'ANDERSON REPAIR'},
#   {'Make_ID': 5988, 'Make_Name': 'ANDERSON TRUCK BODY & EQUIPMENT'},
#   {'Make_ID': 9354,
#    'Make_Name': 'ANDREWS EQUIPMENT SERVICE OF WASHINGTON INC.'},
#   {'Make_ID': 5386, 'Make_Name': 'ANDROS ENGINEERING'},
#   {'Make_ID': 8337, 'Make_Name': "ANDY'S WELDING"},
#   {'Make_ID': 8386, 'Make_Name': "ANESKO'S CUSTOM TRAILERS"},
#   {'Make_ID': 828, 'Make_Name': 'ANHUI ANKAI'},
#   {'Make_ID': 10910, 'Make_Name': 'ANLIE'},
#   {'Make_ID': 12454, 'Make_Name': 'ANTE'},
#   {'Make_ID': 7337, 'Make_Name': 'ANTIOCH'},
#   {'Make_ID': 831, 'Make_Name': 'ANTRIM METALWORKING & REPAIR'},
#   {'Make_ID': 11795, 'Make_Name': 'ANVIL'},
#   {'Make_ID': 9190, 'Make_Name': 'ANVIL PRODUCTS CORPORATION'},
#   {'Make_ID': 832, 'Make_Name': 'ANVIL TRAILER'},
#   {'Make_ID': 6550, 'Make_Name': 'ANYSIZER CHASSIS MANUFACTURING CO'},
#   {'Make_ID': 5402, 'Make_Name': 'ANYTHING GOES CYCLES'},
#   {'Make_ID': 8903, 'Make_Name': 'ANYTHING IN IRON, INC.'},
#   {'Make_ID': 12778, 'Make_Name': 'AODES'},
#   {'Make_ID': 8696, 'Make_Name': 'AP TRAILERS LLC'},
#   {'Make_ID': 3937, 'Make_Name': 'APA'},
#   {'Make_ID': 5991, 'Make_Name': 'APACHE'},
#   {'Make_ID': 833, 'Make_Name': 'APACHE GOLF CARS'},
#   {'Make_ID': 6747, 'Make_Name': 'APACHE SINCA INDUSTRIES INC'},
#   {'Make_ID': 8454, 'Make_Name': 'APACHE TRAILER'},
#   {'Make_ID': 6749, 'Make_Name': 'APC EQUIPMENT'},
#   {'Make_ID': 8673, 'Make_Name': 'APEX CUSTOM TRAILERS'},
#   {'Make_ID': 12534, 'Make_Name': 'APEX ENERGY SVC'},
#   {'Make_ID': 9302, 'Make_Name': 'APEX MANUFACTURING CO.'},
#   {'Make_ID': 834, 'Make_Name': 'APEX MOTOR'},
#   {'Make_ID': 837, 'Make_Name': 'API'},
#   {'Make_ID': 4627, 'Make_Name': 'APLUS TRAILERS'},
#   {'Make_ID': 10424, 'Make_Name': 'APM'},
#   {'Make_ID': 11522, 'Make_Name': 'APOGEE'},
#   {'Make_ID': 10592, 'Make_Name': 'APOGEE TRAILERS'},
#   {'Make_ID': 8453, 'Make_Name': 'APOGEE TRAILERS LLC'},
#   {'Make_ID': 10199, 'Make_Name': 'APOLLO'},
#   {'Make_ID': 839, 'Make_Name': 'APOLLO CHOPPERS'},
#   {'Make_ID': 6088, 'Make_Name': 'APOLLO TRAILER COMPANY'},
#   {'Make_ID': 840, 'Make_Name': 'APPALACHIAN TEARDROP COMPANY'},
#   {'Make_ID': 841, 'Make_Name': 'APPALACHIAN TRAILER SALES'},
#   {'Make_ID': 7931, 'Make_Name': 'APPALACHIAN TRAILERS INC.'},
#   {'Make_ID': 10631, 'Make_Name': 'APPLEQUIST MANUFACTURING, INC.'},
#   {'Make_ID': 7485, 'Make_Name': 'APPLETON STEEL, INC.'},
#   {'Make_ID': 843, 'Make_Name': 'APPLIED CRYO TECHNOLOGIES'},
#   {'Make_ID': 844, 'Make_Name': 'APPLIED RESEARCH/VERTEK'},
#   {'Make_ID': 845, 'Make_Name': 'APRILIA'},
#   {'Make_ID': 7869, 'Make_Name': 'APS SYSTEMS'},
#   {'Make_ID': 3938, 'Make_Name': 'APTERA MOTORS'},
#   {'Make_ID': 6089, 'Make_Name': 'AQUACRAFT INC'},
#   {'Make_ID': 10227, 'Make_Name': 'AQUAHAWK'},
#   {'Make_ID': 12579, 'Make_Name': 'ARABIAN METAL INDUSTRIES LTD.'},
#   {'Make_ID': 10315, 'Make_Name': 'ARBOC'},
#   {'Make_ID': 12248, 'Make_Name': "ARBUCKLE'S HOMES TO GO INC"},
#   {'Make_ID': 11842, 'Make_Name': 'ARC'},
#   {'Make_ID': 11151, 'Make_Name': 'ARC LINE MANUFACTURING LLC'},
#   {'Make_ID': 7129, 'Make_Name': 'ARC MANUFACTURING'},
#   {'Make_ID': 9947, 'Make_Name': 'ARC ZONE'},
#   {'Make_ID': 848, 'Make_Name': 'ARCADE IRON MOTORCYCLE COMPANY'},
#   {'Make_ID': 11082, 'Make_Name': 'ARCADIA'},
#   {'Make_ID': 12886, 'Make_Name': 'ARCANE TRAILERS'},
#   {'Make_ID': 12702, 'Make_Name': 'ARCAS TRAILER'},
#   {'Make_ID': 6603, 'Make_Name': 'ARCH CARGO TRAILERS'},
#   {'Make_ID': 849, 'Make_Name': 'ARCH MOTORCYCLE CO'},
#   {'Make_ID': 12312, 'Make_Name': 'ARCHE OLIVE COMPANY LLC.'},
#   {'Make_ID': 9116, 'Make_Name': 'ARCHER MANUFACTURING CORPORATION'},
#   {'Make_ID': 9447, 'Make_Name': 'ARCHITECTURAL WELDING & DESIGN'},
#   {'Make_ID': 851, 'Make_Name': 'ARCIMOTO'},
#   {'Make_ID': 12162, 'Make_Name': 'ARCS'},
#   {'Make_ID': 12054, 'Make_Name': 'ARCTIC BLAST'},
#   {'Make_ID': 10190, 'Make_Name': 'ARCTIC CAT'},
#   {'Make_ID': 11518, 'Make_Name': 'ARCTICMAX'},
#   {'Make_ID': 850, 'Make_Name': 'ARCWELD'},
#   {'Make_ID': 12977, 'Make_Name': 'ARE - 1'},
#   {'Make_ID': 9681, 'Make_Name': 'AREA 51'},
#   {'Make_ID': 6065, 'Make_Name': 'ARENA WERKS'},
#   {'Make_ID': 8028, 'Make_Name': 'ARGO FAB, INC'},
#   {'Make_ID': 5128, 'Make_Name': 'ARGO TRAILERS'},
#   {'Make_ID': 11461, 'Make_Name': 'ARGO TRAILERS GA'},
#   {'Make_ID': 12442, 'Make_Name': 'ARION'},
#   {'Make_ID': 852, 'Make_Name': 'ARISING INDUSTRIES, INC'},
#   {'Make_ID': 9281, 'Make_Name': 'ARISTOCRAT INDUSTRIES, INC.'},
#   {'Make_ID': 8744, 'Make_Name': 'ARIZONA MACHINE & FABRICATION, INC.'},
#   {'Make_ID': 1139, 'Make_Name': 'ARIZONA TRAILER MANUFACTURING'},
#   {'Make_ID': 1143, 'Make_Name': 'ARIZONA TRAILER SPECIALISTS'},
#   {'Make_ID': 6547, 'Make_Name': 'ARIZONA WOODRIVER OUTFITTERS, LLC'},
#   {'Make_ID': 7338, 'Make_Name': 'ARK CUSTOM TRAILERS'},
#   {'Make_ID': 12387, 'Make_Name': 'ARKANSAS BOATS LLC'},
#   {'Make_ID': 1152, 'Make_Name': 'ARKFELD'},
#   {'Make_ID': 11231, 'Make_Name': 'ARKTO CAMPERS LTD.'},
#   {'Make_ID': 8739, 'Make_Name': 'ARLEN NESS ENTERPRISES, INC.'},
#   {'Make_ID': 4569, 'Make_Name': 'ARMADILLO CAMPER KITS'},
#   {'Make_ID': 11180, 'Make_Name': 'ARMADILLO TRAILER MFG.'},
#   {'Make_ID': 5367, 'Make_Name': 'ARMBRUSTER STAGEWAY'},
#   {'Make_ID': 11052, 'Make_Name': 'ARMLIFT'},
#   {'Make_ID': 11080, 'Make_Name': 'ARMOR CARGO TRAILERS, LLC'},
#   {'Make_ID': 6130, 'Make_Name': 'ARMOR CHASSIS'},
#   {'Make_ID': 10849, 'Make_Name': 'ARMOR LITE '},
#   {'Make_ID': 9669, 'Make_Name': 'ARMOR LITE EXCEL, LLC'},
#   {'Make_ID': 1161, 'Make_Name': 'ARMOR LITE TRAILER'},
#   {'Make_ID': 12091, 'Make_Name': 'ARMORTECK'},
#   {'Make_ID': 6612, 'Make_Name': 'ARMSTRONG TRAILER MANUFACTURING CO., INC.'},
#   {'Make_ID': 7726, 'Make_Name': 'ARMSTRONG TRAILER PRODUCTS, INC.'},
#   {'Make_ID': 5129, 'Make_Name': 'ARMSTRONG TRAILERS'},
#   {'Make_ID': 9130, 'Make_Name': 'ARNDT TRAILER MANUFACTURING'},
#   {'Make_ID': 8995, 'Make_Name': 'ARNING INDUSTRIES, INC.'},
#   {'Make_ID': 1165, 'Make_Name': 'ARNOLD MACHINE'},
#   {'Make_ID': 6837, 'Make_Name': 'ARO SA'},
#   {'Make_ID': 9453, 'Make_Name': 'ARRIBA CUEBALL TRAILER MFG L.L.C.'},
#   {'Make_ID': 8228, 'Make_Name': 'ARROW DUMP TRAILERS'},
#   {'Make_ID': 10087, 'Make_Name': 'ARROW TANK AND ENGINEERING CO.'},
#   {'Make_ID': 6687, 'Make_Name': 'ARROWHEAD'},
#   {'Make_ID': 8688, 'Make_Name': 'ARROWHEAD TRAILER MFG., INC.'},
#   {'Make_ID': 1171, 'Make_Name': 'ARSENAL OF VIRGINIA'},
#   {'Make_ID': 7796, 'Make_Name': 'ARSENAL TRAILER MANUFACTURING INC'},
#   {'Make_ID': 10307, 'Make_Name': 'ART'},
#   {'Make_ID': 1180, 'Make_Name': 'ART IN MOTION'},
#   {'Make_ID': 5706, 'Make_Name': 'ART ROLL TECH'},
#   {'Make_ID': 5046, 'Make_Name': "ART'S PORTABLE WELDING"},
#   {'Make_ID': 10674, 'Make_Name': "ART'S WAY"},
#   {'Make_ID': 1187, 'Make_Name': 'ARTECH PARTS FABRICATION'},
#   {'Make_ID': 12820, 'Make_Name': 'ARVI TRAILERS'},
#   {'Make_ID': 11963, 'Make_Name': 'ASA'},
#   {'Make_ID': 1194, 'Make_Name': 'ASC, INC.'},
#   {'Make_ID': 5502, 'Make_Name': 'ASE'},
#   {'Make_ID': 9100, 'Make_Name': 'ASH COMPANY OF MOUNTAIN LAKE'},
#   {'Make_ID': 9235, 'Make_Name': 'ASHCAN FAB. CO.'},
#   {'Make_ID': 1197, 'Make_Name': 'ASHCROFT ENTERPRISES'},
#   {'Make_ID': 5697, 'Make_Name': 'ASHFORD MFG'},
#   {'Make_ID': 12182, 'Make_Name': "ASHLEY'S CAROLINA CARS"},
#   {'Make_ID': 11230, 'Make_Name': "ASHLEY'S WELDING AND METAL FABRICATION"},
#   {'Make_ID': 7250, 'Make_Name': 'ASI TRAILERS'},
#   {'Make_ID': 12652, 'Make_Name': 'ASPEN'},
#   {'Make_ID': 12898, 'Make_Name': 'ASPEN (KEB)'},
#   {'Make_ID': 11816, 'Make_Name': 'ASPEN CUSTOM TRAILERS'},
#   {'Make_ID': 11083, 'Make_Name': 'ASPEN TRAIL'},
#   {'Make_ID': 9534, 'Make_Name': 'ASPEN TRAILER COMPANY LTD.'},
#   {'Make_ID': 6801, 'Make_Name': 'ASPEN TRAILER INC.'},
#   {'Make_ID': 3940, 'Make_Name': 'ASPHALT EQUIPMENT & SERVICE'},
#   {'Make_ID': 5698, 'Make_Name': 'ASPHALT MACHINERY'},
#   {'Make_ID': 7390, 'Make_Name': 'ASPHALT ZIPPER INC'},
#   {'Make_ID': 1511, 'Make_Name': 'ASPHALT ZIPPER TRAILER'},
#   {'Make_ID': 9788, 'Make_Name': 'ASSAULT TRAILERS LLC'},
#   {'Make_ID': 8403, 'Make_Name': 'ASSOCIATED SIDE DUMP DEVELOPMENT, INC.'},
#   {'Make_ID': 6769, 'Make_Name': 'ASTEC INDUSTRIES INC.'},
#   {'Make_ID': 1199, 'Make_Name': 'ASTEC MOBILE SCREENS'},
#   {'Make_ID': 1202, 'Make_Name': 'ASTEC UNDERGROUND'},
#   {'Make_ID': 440, 'Make_Name': 'ASTON MARTIN'},
#   {'Make_ID': 11877, 'Make_Name': 'ASTON METAL ART'},
#   {'Make_ID': 11084, 'Make_Name': 'ASTORIA'},
#   {'Make_ID': 6771, 'Make_Name': 'ASTORIA INDUSTRIES, INC.'},
#   {'Make_ID': 12983, 'Make_Name': 'ASTRA STAGES'},
#   {'Make_ID': 9862, 'Make_Name': 'ASTRO HAVEN ENTERPRISES'},
#   {'Make_ID': 8088, 'Make_Name': 'ASTUR N.C. TOOLING, INC'},
#   {'Make_ID': 5464, 'Make_Name': 'ASUNA'},
#   {'Make_ID': 12085, 'Make_Name': 'ATC TRAILERS'},
#   {'Make_ID': 1236, 'Make_Name': 'ATEC AANHANGWAGENS'},
#   {'Make_ID': 3941, 'Make_Name': 'ATEK TRAILERS'},
#   {'Make_ID': 9488, 'Make_Name': 'ATF MFG, LLC'},
#   {'Make_ID': 10610, 'Make_Name': 'ATG'},
#   {'Make_ID': 12460, 'Make_Name': 'ATHENS OVERLAND'},
#   {'Make_ID': 5820, 'Make_Name': 'ATK'},
#   {'Make_ID': 12632, 'Make_Name': 'ATLANT'},
#   {'Make_ID': 5993, 'Make_Name': 'ATLANTA FABRICATING & EQUIPMENT CO'},
#   {'Make_ID': 12160, 'Make_Name': 'ATLANTIC MARINE TRAILERS'},
#   {'Make_ID': 6405, 'Make_Name': 'ATLANTIC TRAILERS'},
#   {'Make_ID': 4762, 'Make_Name': 'ATLAS'},
#   {'Make_ID': 12406, 'Make_Name': 'ATLAS (VEXAS CORP.)'},
#   {'Make_ID': 7426, 'Make_Name': 'ATLAS COPCO'},
#   {'Make_ID': 1239, 'Make_Name': 'ATLAS CUSTOM TRAILERS'},
#   {'Make_ID': 4967, 'Make_Name': 'ATLAS LIFT TRAILERS, INC.'},
#   {'Make_ID': 7690, 'Make_Name': 'ATLAS MFG CO INC'},
#   {'Make_ID': 8243, 'Make_Name': 'ATLAS SPECIALTY PRODUCTS'},
#   {'Make_ID': 3957, 'Make_Name': 'ATOKA TRAILER & MFG.'},
#   {'Make_ID': 5269, 'Make_Name': 'ATOMIC ELECTRIC VEHICLES'},
#   {'Make_ID': 3723, 'Make_Name': 'ATR'},
#   {'Make_ID': 9883, 'Make_Name': 'ATRO'},
#   {'Make_ID': 6588, 'Make_Name': 'ATSATV'},
#   {'Make_ID': 4846, 'Make_Name': 'ATT R&D'},
#   {'Make_ID': 6514, 'Make_Name': 'ATTITUDE CUSTOM CYCLES, INC.'},
#   {'Make_ID': 7013, 'Make_Name': 'ATWOOD TRAILERS'},
#   {'Make_ID': 9246, 'Make_Name': 'AUCTIONEERING SYSTEMS, INC.'},
#   {'Make_ID': 11991, 'Make_Name': 'AUDETTE'},
#   {'Make_ID': 582, 'Make_Name': 'AUDI'},
#   {'Make_ID': 9492, 'Make_Name': 'AUGUST METAL WORKS'},
#   {'Make_ID': 1252, 'Make_Name': 'AUGUSTA RV'},
#   {'Make_ID': 10022, 'Make_Name': 'AULICK INDUSTRIES'},
#   {'Make_ID': 9381, 'Make_Name': 'AURORA MODULAR INDUSTRIES'},
#   {'Make_ID': 1254, 'Make_Name': 'AURORA TRAILERS'},
#   {'Make_ID': 10625, 'Make_Name': 'AUSRV INC.'},
#   {'Make_ID': 8245, 'Make_Name': 'AUSTIN ELECTRIC'},
#   {'Make_ID': 6487, 'Make_Name': 'AUSTIN EV METRO'},
#   {'Make_ID': 1257, 'Make_Name': 'AUSTIN WELDING SERVICE'},
#   {'Make_ID': 11194, 'Make_Name': 'AUSTRALIAN OFF ROAD'},
#   {'Make_ID': 8603, 'Make_Name': 'AUTO CRAFT WHOLESALE AUTO'},
#   {'Make_ID': 8249, 'Make_Name': 'AUTO DECOR MATANE INC.'},
#   {'Make_ID': 5380, 'Make_Name': 'AUTO MOTION IND.'},
#   {'Make_ID': 1263, 'Make_Name': 'AUTO TANQUES Y TOLVAS TROY S.A. DE C.V.'},
#   {'Make_ID': 9157, 'Make_Name': 'AUTO TRANSPORT SERVICE'},
#   {'Make_ID': 4602, 'Make_Name': 'AUTO TRUCK'},
#   {'Make_ID': 6754, 'Make_Name': 'AUTO-MANIA'},
#   {'Make_ID': 1297, 'Make_Name': 'AUTOCAR'},
#   {'Make_ID': 1331, 'Make_Name': 'AUTOCAR INDUSTRIES'},
#   {'Make_ID': 8395, 'Make_Name': 'AUTOCAR LTD'},
#   {'Make_ID': 10968, 'Make_Name': 'AUTOCYCLE LLC'},
#   {'Make_ID': 7836, 'Make_Name': 'AUTODELTA USA INC'},
#   {'Make_ID': 1483, 'Make_Name': 'AUTOKAD'},
#   {'Make_ID': 9983, 'Make_Name': 'AUTOMATED BIOMASS SYSTEMS'},
#   {'Make_ID': 5994, 'Make_Name': 'AUTOMATED ENGINEERING SYSTEMS INC'},
#   {'Make_ID': 8956, 'Make_Name': 'AUTOMATED WASTE EQUIPMENT CO., INC.'},
#   {'Make_ID': 11346, 'Make_Name': 'AUTOMOBILI PININFARINA'},
#   {'Make_ID': 7903, 'Make_Name': 'AUTOMOTIVE TRANSFORMATION INC.'},
#   {'Make_ID': 11730, 'Make_Name': 'AUTUMN RIDGE'},
#   {'Make_ID': 12279, 'Make_Name': 'AUTUMNCREST ENTERPRISES LLC'},
#   {'Make_ID': 11181,
#    'Make_Name': 'AUWAERTER-ANHAENGER UND AUFBAUTEN GMBH & CO. KG'},
#   {'Make_ID': 8715, 'Make_Name': 'AVAILABLE MATERIALS HANDLING'},
#   {'Make_ID': 11087, 'Make_Name': 'AVALANCHE'},
#   {'Make_ID': 5552, 'Make_Name': 'AVANTI'},
#   {'Make_ID': 8562, 'Make_Name': 'AVANTI MARINE USA INC.'},
#   {'Make_ID': 1488, 'Make_Name': 'AVANTI MOTORCYCLES'},
#   {'Make_ID': 1498, 'Make_Name': 'AVERA MOTORS'},
#   {'Make_ID': 8168, 'Make_Name': 'AVESCO WELDING & FABRICATION'},
#   {'Make_ID': 6380, 'Make_Name': 'AVILA MANUFACTURING'},
#   {'Make_ID': 12996, 'Make_Name': 'AW CUSTOM TRAILER’S LLC'},
#   {'Make_ID': 10396, 'Make_Name': 'AWC'},
#   {'Make_ID': 1592, 'Make_Name': 'AWESOME REBUILD'},
#   {'Make_ID': 11928, 'Make_Name': 'AWS TRAILERS'},
#   {'Make_ID': 12569, 'Make_Name': 'AXIS'},
#   {'Make_ID': 6035, 'Make_Name': 'AXIS CORPORATION'},
#   {'Make_ID': 12280, 'Make_Name': 'AYRO'},
#   {'Make_ID': 7055, 'Make_Name': 'AZIMUTH INC.'},
#   {'Make_ID': 1522, 'Make_Name': 'AZLAND'},
#   {'Make_ID': 1523, 'Make_Name': 'AZTEC TRAILER'},
#   {'Make_ID': 10206, 'Make_Name': 'AZURE DYNAMIC INC.'},
#   {'Make_ID': 1533, 'Make_Name': 'AZURE DYNAMICS'},
#   {'Make_ID': 3958, 'Make_Name': 'B & B ENTERPRISES'},
#   {'Make_ID': 8039, 'Make_Name': 'B & B FABRICATORS'},
#   {'Make_ID': 7257, 'Make_Name': 'B & B TRAILER SALES'},
#   {'Make_ID': 7310, 'Make_Name': 'B & B TRAILERS'},
#   {'Make_ID': 12981, 'Make_Name': 'B & B TRAILERS OF SAVANNAH'},
#   {'Make_ID': 9179, 'Make_Name': 'B & E TRAILER SALES INC.'},
#   {'Make_ID': 9410, 'Make_Name': 'B & G SUPPLY'},
#   {'Make_ID': 3959, 'Make_Name': 'B & H CUSTOMS'},
#   {'Make_ID': 8941, 'Make_Name': 'B & H TRAILERS'},
#   {'Make_ID': 9117, 'Make_Name': 'B & H WELDING SERVICES'},
#   {'Make_ID': 9189, 'Make_Name': 'B & K TRAILERS, INC.'},
#   {'Make_ID': 9164, 'Make_Name': 'B & L TRAILER MANUFACTURER'},
#   {'Make_ID': 8960, 'Make_Name': 'B & M ENTERPRISES'},
#   {'Make_ID': 6737, 'Make_Name': 'B & M HI-LITE'},
#   {'Make_ID': 1542, 'Make_Name': 'B & M MANUFACTURING'},
#   {'Make_ID': 5572, 'Make_Name': 'B & M TRAILER SALES'},
#   {'Make_ID': 9013, 'Make_Name': 'B & O CUSTOM TRAILERS'},
#   {'Make_ID': 1543, 'Make_Name': 'B & R TRAILERS'},
#   {'Make_ID': 7244, 'Make_Name': 'B & R WELDING'},
#   {'Make_ID': 8993, 'Make_Name': 'B & S CONCESSION'},
#   {'Make_ID': 7019, 'Make_Name': 'B & S TRAILER SALES'},
#   {'Make_ID': 6738, 'Make_Name': 'B & T MANUFACTURING DBA XTREME TRAILER'},
#   {'Make_ID': 7925, 'Make_Name': 'B & W CONSTRUCTION'},
#   {'Make_ID': 11497, 'Make_Name': 'B & W FABRICATION, LLC'},
#   {'Make_ID': 11496, 'Make_Name': 'B & W FABRICATION, LLC / RED RHINO'},
#   {'Make_ID': 3960, 'Make_Name': 'B & W MANTRAD'},
#   {'Make_ID': 7245, 'Make_Name': 'B & W TRAILERS'},
#   {'Make_ID': 11356, 'Make_Name': 'B AND L FABRICATION'},
#   {'Make_ID': 11467, 'Make_Name': 'B AND L TRAILERS'},
#   {'Make_ID': 5130, 'Make_Name': 'B AND M TRAILER SALES'},
#   {'Make_ID': 10350, 'Make_Name': 'B AND M TRAILERS LLC'},
#   {'Make_ID': 9721, 'Make_Name': 'B AND S SUPPLY'},
#   {'Make_ID': 7063, 'Make_Name': "B B'S TRAILERS"},
#   {'Make_ID': 6455, 'Make_Name': 'B&A TRAILERS INC.'},
#   {'Make_ID': 6726, 'Make_Name': 'B&B MICRO MANUFACTURING INC'},
#   {'Make_ID': 5564, 'Make_Name': 'B&D'},
#   {'Make_ID': 9927, 'Make_Name': 'B&G TRAILERS INC'},
#   {'Make_ID': 9736, 'Make_Name': 'B&K TRAILERS'},
#   {'Make_ID': 1595, 'Make_Name': 'B&M PERFORMANCE CYCLES'},
#   {'Make_ID': 5528, 'Make_Name': 'B&W'},
#   {'Make_ID': 8742, 'Make_Name': 'B&W WELDING & REPAIR'},
#   {'Make_ID': 6723, 'Make_Name': "B'S IN A POD CAMPING LLC"},
#   {'Make_ID': 1602, 'Make_Name': 'B+B TRAILERS'},
#   {'Make_ID': 7234, 'Make_Name': 'B-LINE CORPORATION'},
#   {'Make_ID': 6979, 'Make_Name': 'B-WELDING'},
#   {'Make_ID': 7498, 'Make_Name': 'B.C. TRAILERS INC'},
#   {'Make_ID': 3963, 'Make_Name': 'B.E.E. WELDING'},
#   {'Make_ID': 13071, 'Make_Name': 'B.E.S.T'},
#   {'Make_ID': 7133, 'Make_Name': 'B.K. JONES BUILDERS LLC'},
#   {'Make_ID': 6739, 'Make_Name': 'B.L. INDUSTRIES, INC.'},
#   {'Make_ID': 3976, 'Make_Name': 'B.T. CUSTOM TRAILERS'},
#   {'Make_ID': 4695, 'Make_Name': 'B.T.L. TRAILERS'},
#   {'Make_ID': 1604, 'Make_Name': 'BACH BUILT CHOPPERS'},
#   {'Make_ID': 7464, 'Make_Name': 'BACK 40 CREATIONS'},
#   {'Make_ID': 1605, 'Make_Name': 'BACK 40 SUPPLY'},
#   {'Make_ID': 9476, 'Make_Name': 'BACK OFF LOWBOYS'},
#   {'Make_ID': 10726, 'Make_Name': 'BACK PORCH HOMES'},
#   {'Make_ID': 3977, 'Make_Name': 'BACK TRACK TRAILERS'},
#   {'Make_ID': 1609, 'Make_Name': 'BACK YARD CHOPPERS'},
#   {'Make_ID': 1606, 'Make_Name': 'BACKROAD CHOPPERS'},
#   {'Make_ID': 10956, 'Make_Name': 'BACKROADS OVERLOAD CO.'},
#   {'Make_ID': 12915, 'Make_Name': 'BACKSTREET SURVEILLANCE'},
#   {'Make_ID': 7738, 'Make_Name': 'BACKTREK'},
#   {'Make_ID': 7159, 'Make_Name': 'BACKWATER TRAILERS'},
#   {'Make_ID': 10527, 'Make_Name': 'BACKWATER-CUSTOMS'},
#   {'Make_ID': 1610, 'Make_Name': 'BACKWOODS CHOPPERS'},
#   {'Make_ID': 8625, 'Make_Name': 'BACKWOODS TRAILER SALES & MANUFACTURER'},
#   {'Make_ID': 1611, 'Make_Name': 'BACKYARD CHOPPERS'},
#   {'Make_ID': 12102, 'Make_Name': 'BACKYARD STRUCTURES'},
#   {'Make_ID': 7775, 'Make_Name': 'BACKYARD TRAILERS, LLC'},
#   {'Make_ID': 1612, 'Make_Name': 'BAD 2D BONE TRAILERS'},
#   {'Make_ID': 5026, 'Make_Name': 'BAD ASS CHOPPERS'},
#   {'Make_ID': 12571, 'Make_Name': 'BAD BOY'},
#   {'Make_ID': 5424, 'Make_Name': 'BAD BOY BUGGY'},
#   {'Make_ID': 1613, 'Make_Name': 'BAD BOY ENTERPRISES'},
#   {'Make_ID': 3978, 'Make_Name': 'BAD BOY INC.'},
#   {'Make_ID': 1615, 'Make_Name': 'BAD BOY TRAILERS'},
#   {'Make_ID': 1623, 'Make_Name': 'BAD BOYS CHOPPERS'},
#   {'Make_ID': 1626, 'Make_Name': 'BAD BOYZ TOYZ'},
#   {'Make_ID': 1643, 'Make_Name': 'BAD ISLAND TOYZ'},
#   {'Make_ID': 10834, 'Make_Name': 'BADAC'},
#   {'Make_ID': 1651, 'Make_Name': 'BADASS INDUSTRIES'},
#   {'Make_ID': 3980, 'Make_Name': 'BADGE BOYZ CUSTOMZ'},
#   {'Make_ID': 1657, 'Make_Name': 'BADGER EQUIPMENT'},
#   {'Make_ID': 8743, 'Make_Name': 'BADGER UTILITY INC.'},
#   {'Make_ID': 1669, 'Make_Name': 'BADLANDS STEEL WORX'},
#   {'Make_ID': 5096, 'Make_Name': 'BADSEY BULLET U.S.A, INC.'},
#   {'Make_ID': 12544, 'Make_Name': 'BAGGETS RETAIL TRAILER SALES'},
#   {'Make_ID': 3981, 'Make_Name': "BAGGETT'S TRAILER CONNECTION"},
#   {'Make_ID': 8318, 'Make_Name': 'BAGLEY INC.'},
#   {'Make_ID': 1670, 'Make_Name': 'BAHN WAGEN'},
#   {'Make_ID': 6908, 'Make_Name': 'BAHR CUSTOM BOATS & TRAILERS'},
#   {'Make_ID': 8534, 'Make_Name': 'BAILLIE DIESEL, INC.'},
#   {'Make_ID': 1671, 'Make_Name': 'BAIR BODIES AND TRAILERS'},
#   {'Make_ID': 5498, 'Make_Name': 'BAIRD & SLASKA MFG'},
#   {'Make_ID': 1674, 'Make_Name': 'BAJA CUSTOM TRAILERS'},
#   {'Make_ID': 6048, 'Make_Name': 'BAJA STEEL INC'},
#   {'Make_ID': 4007, 'Make_Name': 'BAJAJ AUTO'},
#   {'Make_ID': 5997, 'Make_Name': 'BAKER'},
#   {'Make_ID': 1680, 'Make_Name': 'BAKERS TRAILER'},
#   {'Make_ID': 1683, 'Make_Name': 'BAKKURA MOBILITY'},
#   {'Make_ID': 11248, 'Make_Name': 'BAKU TRAILERS'},
#   {'Make_ID': 9042, 'Make_Name': 'BALBI RIMORCHI SRL'},
#   {'Make_ID': 1686, 'Make_Name': 'BALDOR GENERATORS'},
#   {'Make_ID': 8371, 'Make_Name': 'BALE RUNNER MFG.'},
#   {'Make_ID': 8113, 'Make_Name': 'BALES EQUIPMENT TRAILERS LLC'},
#   {'Make_ID': 5998, 'Make_Name': 'BALESTRA'},
#   {'Make_ID': 6191, 'Make_Name': 'BALKO'},
#   {'Make_ID': 6940, 'Make_Name': 'BALLARD POWER SYSTEMS INC.'},
#   {'Make_ID': 7652, 'Make_Name': 'BALLEWS'},
#   {'Make_ID': 12783, 'Make_Name': 'BALLISTIC'},
#   {'Make_ID': 9498, 'Make_Name': 'BALLISTIC TRAILERS'},
#   {'Make_ID': 1727, 'Make_Name': 'BALON CORPORATION'},
#   {'Make_ID': 7542, 'Make_Name': 'BALTIC INDUSTRIES INC'},
#   {'Make_ID': 4626, 'Make_Name': 'BALZER'},
#   {'Make_ID': 5272, 'Make_Name': 'BAMA LSV'},
#   {'Make_ID': 10658, 'Make_Name': 'BANDIT'},
#   {'Make_ID': 5579, 'Make_Name': 'BANDIT CHOPPERS LLC'},
#   {'Make_ID': 11830, 'Make_Name': 'BANDIT TRAILERS, LLC'},
#   {'Make_ID': 7978, 'Make_Name': 'BANDY TRAILERS'},
#   {'Make_ID': 5351, 'Make_Name': 'BANENS'},
#   {'Make_ID': 3127, 'Make_Name': 'BANTAM TRAILERS USA'},
#   {'Make_ID': 3115, 'Make_Name': 'BAODIAO'},
#   {'Make_ID': 1731, 'Make_Name': 'BAR H WELDING'},
#   {'Make_ID': 8333, 'Make_Name': 'BAR T Z UNLIMITED'},
#   {'Make_ID': 6117, 'Make_Name': 'BAR Y'},
#   {'Make_ID': 5687, 'Make_Name': 'BAR-BEL FABRICATING'},
#   {'Make_ID': 4916, 'Make_Name': 'BARCLAY TRUCK REBUILDERS'},
#   {'Make_ID': 7567, 'Make_Name': 'BARCO INDUSTRIAL SUPPLY'},
#   {'Make_ID': 10367, 'Make_Name': 'BARCO PUMP CO.'},
#   {'Make_ID': 6118, 'Make_Name': 'BARCROFT WELDING AND ORNAMENTAL IRON'},
#   {'Make_ID': 1732, 'Make_Name': 'BARE KNUCKLE CHOPPERS'},
#   {'Make_ID': 10071, 'Make_Name': 'BARE METAL, LLC'},
#   {'Make_ID': 6119, 'Make_Name': "BARLOW'S WELDING"},
#   {'Make_ID': 5362, 'Make_Name': 'BARNSTORM CYCLES'},
#   {'Make_ID': 11483, 'Make_Name': 'BARNTS SALES COMPANY LLC'},
#   {'Make_ID': 1733, 'Make_Name': 'BARNYARD CUSTOMS'},
#   {'Make_ID': 6549, 'Make_Name': 'BARON MOTORCYCLES, INC.'},
#   {'Make_ID': 5132, 'Make_Name': 'BARON USA INC'},
#   {'Make_ID': 1734, 'Make_Name': 'BARRETO MANUFACTURING'},
#   {'Make_ID': 11134, 'Make_Name': 'BARRETT TRAILERS'},
#   {'Make_ID': 5076, 'Make_Name': 'BARRETT TRAILERS, INC.'},
#   {'Make_ID': 1743, 'Make_Name': 'BARRIER SYSTEMS'},
#   {'Make_ID': 1745, 'Make_Name': 'BARRO AG WELDING AND TRAILER REPAIR'},
#   {'Make_ID': 1747, 'Make_Name': "BARRY'S TRAILERS"},
#   {'Make_ID': 10684, 'Make_Name': 'BARSTOW KUSTOM '},
#   {'Make_ID': 7314, 'Make_Name': 'BARTEL WELDING'},
#   {'Make_ID': 6240, 'Make_Name': 'BARTLEY CORPORATION'},
#   {'Make_ID': 8802, 'Make_Name': 'BARTON INVESTMENT GROUP MANUFACTURING, LLC'},
#   {'Make_ID': 1778, 'Make_Name': 'BASE CAMP RECREATIONAL VEHICLES'},
#   {'Make_ID': 2976, 'Make_Name': 'BASECAMP'},
#   {'Make_ID': 2080, 'Make_Name': 'BASHAN'},
#   {'Make_ID': 12720, 'Make_Name': 'BASHAN/BMS'},
#   {'Make_ID': 12721, 'Make_Name': 'BASHAN/RAVEN'},
#   {'Make_ID': 13048, 'Make_Name': 'BASHI'},
#   {'Make_ID': 9051, 'Make_Name': 'BASOGLU KARAVAN SANAYI VE TICARET A.S.'},
#   {'Make_ID': 9119, 'Make_Name': 'BASSCAT'},
#   {'Make_ID': 5270, 'Make_Name': 'BATCO'},
#   {'Make_ID': 1083, 'Make_Name': 'BATTLE WAGON TRAILERS'},
#   {'Make_ID': 11933, 'Make_Name': 'BATTLE WAGON TRAILERS (KTD INDUSTRIES)'},
#   {'Make_ID': 5103, 'Make_Name': 'BAUER'},
#   {'Make_ID': 8951, 'Make_Name': 'BAUER BUILT MANUFACTURING, INC.'},
#   {'Make_ID': 1780, 'Make_Name': 'BAUGHMAN PRODUCTS'},
#   {'Make_ID': 5273, 'Make_Name': 'BAUSS MANUFACTURING INC.'},
#   {'Make_ID': 7830,
#    'Make_Name': 'BAUTISTA WELDING & CUSTOM TRAILERS MANUFACTURING LLC'},
#   {'Make_ID': 10892, 'Make_Name': 'BAUXLITE'},
#   {'Make_ID': 11203, 'Make_Name': 'BAY AREA METAL FABRICATION'},
#   {'Make_ID': 1785, 'Make_Name': 'BAY BRIDGE MANUFACTURING'},
#   {'Make_ID': 1787, 'Make_Name': 'BAY CITY CHOPPERS'},
#   {'Make_ID': 7119, 'Make_Name': 'BAY EQUIPMENT AND REPAIR (BEAR)'},
#   {'Make_ID': 1790, 'Make_Name': 'BAY MANUFACTURING'},
#   {'Make_ID': 3911, 'Make_Name': 'BAY TOWN CHOPPERS'},
#   {'Make_ID': 5602, 'Make_Name': 'BAYER TRAILERS'},
#   {'Make_ID': 5452, 'Make_Name': 'BAYSHORE'},
#   {'Make_ID': 7841, 'Make_Name': 'BAYSHORE SYSTEMS, INC'},
#   {'Make_ID': 6909, 'Make_Name': 'BAZ MFG.'},
#   {'Make_ID': 1792, 'Make_Name': 'BAZOOKA FARMSTAR TRAILERS'},
#   {'Make_ID': 10564, 'Make_Name': "BAZZELL'S"},
#   {'Make_ID': 1810, 'Make_Name': 'BB BUGGIES'},
#   {'Make_ID': 1794, 'Make_Name': 'BB ROLLAHOME'},
#   {'Make_ID': 8605, 'Make_Name': 'BBC'},
#   {'Make_ID': 6485, 'Make_Name': 'BBK'},
#   {'Make_ID': 11478, 'Make_Name': 'BBQ PITS BY KLOSE'},
#   {'Make_ID': 12836, 'Make_Name': 'BC'},
#   {'Make_ID': 6611, 'Make_Name': 'BC TRAILERS'},
#   {'Make_ID': 7658, 'Make_Name': 'BCA FABRICATION LLC'},
#   {'Make_ID': 7094, 'Make_Name': 'BCA INDUSTRIES'},
#   {'Make_ID': 10973, 'Make_Name': 'BCD TRAILER LLC'},
#   {'Make_ID': 7951, 'Make_Name': 'BCI MANUFACTURING'},
#   {'Make_ID': 5474, 'Make_Name': 'BCI TRAILERS'},
#   {'Make_ID': 10275, 'Make_Name': 'BCL FABRICATION'},
#   {'Make_ID': 12391, 'Make_Name': 'BCT'},
#   {'Make_ID': 1805, 'Make_Name': 'BE SEEN ADVERTISING AND CUSTOM DESIGNS'},
#   {'Make_ID': 7723, 'Make_Name': 'BEACH CITY MOTORCYCLES'},
#   {'Make_ID': 5133, 'Make_Name': 'BEACH KING INC'},
#   {'Make_ID': 4862, 'Make_Name': 'BEALL TRAILERS'},
#   ...]}

# %%
# Example 2 - get all the vehicle types that subaru makes in a CSV file
subaru_makes = extract_vehicle_data("getmakeformanufacturer","subaru")
subaru_makes
# Out:
# Extracting data from https://vpic.nhtsa.dot.gov/api/vehicles/getmakeformanufacturer/subaru
# {'Count': 6,
#  'Message': 'Results returned successfully',
#  'SearchCriteria': 'Manufacturer:subaru',
#  'Results': [{'Make_ID': 448,
#    'Make_Name': 'TOYOTA',
#    'Mfr_Name': 'FUJI HEAVY INDUSTRIES U.S.A., INC. (C/O SUBARU OF AMERICA)'},
#   {'Make_ID': 448, 'Make_Name': 'TOYOTA', 'Mfr_Name': 'SUBARU CORPORATION'},
#   {'Make_ID': 523,
#    'Make_Name': 'SUBARU',
#    'Mfr_Name': 'FUJI HEAVY INDUSTRIES U.S.A., INC. (C/O SUBARU OF AMERICA)'},
#   {'Make_ID': 523,
#    'Make_Name': 'SUBARU',
#    'Mfr_Name': 'SUBARU OF AMERICA, INC'},
#   {'Make_ID': 523, 'Make_Name': 'SUBARU', 'Mfr_Name': 'SUBARU CORPORATION'},
#   {'Make_ID': 572,
#    'Make_Name': 'SAAB',
#    'Mfr_Name': 'FUJI HEAVY INDUSTRIES U.S.A., INC. (C/O SUBARU OF AMERICA)'}]}

# %%
# Exercise 1 - from the API endpoint - get all models for the make toyota
toyota_makes = extract_vehicle_data("getmodelsformake","toyota")
toyota_makes
# Out:
# Extracting data from https://vpic.nhtsa.dot.gov/api/vehicles/getmodelsformake/toyota
# {'Count': 56,
#  'Message': 'Response returned successfully',
#  'SearchCriteria': 'Make:toyota',
#  'Results': [{'Make_ID': 448,
#    'Make_Name': 'Toyota',
#    'Model_ID': 2206,
#    'Model_Name': 'Scion xA'},
#   {'Make_ID': 448,
#    'Make_Name': 'Toyota',
#    'Model_ID': 2207,
#    'Model_Name': 'Scion tC'},
#   {'Make_ID': 448,
#    'Make_Name': 'Toyota',
#    'Model_ID': 2208,
#    'Model_Name': 'Corolla'},
#   {'Make_ID': 448,
#    'Make_Name': 'Toyota',
#    'Model_ID': 2209,
#    'Model_Name': 'Prius'},
#   {'Make_ID': 448,
#    'Make_Name': 'Toyota',
#    'Model_ID': 2210,
#    'Model_Name': 'Scion xB'},
#   {'Make_ID': 448,
#    'Make_Name': 'Toyota',
#    'Model_ID': 2211,
#    'Model_Name': 'Land Cruiser'},
#   {'Make_ID': 448,
#    'Make_Name': 'Toyota',
#    'Model_ID': 2213,
#    'Model_Name': 'Highlander'},
#   {'Make_ID': 448,
#    'Make_Name': 'Toyota',
#    'Model_ID': 2216,
#    'Model_Name': '4-Runner'},
#   {'Make_ID': 448,
#    'Make_Name': 'Toyota',
#    'Model_ID': 2217,
#    'Model_Name': 'RAV4'},
#   {'Make_ID': 448,
#    'Make_Name': 'Toyota',
#    'Model_ID': 2223,
#    'Model_Name': 'Tacoma'},
#   {'Make_ID': 448,
#    'Make_Name': 'Toyota',
#    'Model_ID': 2315,
#    'Model_Name': 'Scion FR-S'},
#   {'Make_ID': 448,
#    'Make_Name': 'Toyota',
#    'Model_ID': 2463,
#    'Model_Name': 'FJ Cruiser'},
#   {'Make_ID': 448,
#    'Make_Name': 'Toyota',
#    'Model_ID': 2464,
#    'Model_Name': 'Yaris'},
#   {'Make_ID': 448,
#    'Make_Name': 'Toyota',
#    'Model_ID': 2465,
#    'Model_Name': 'Avalon'},
#   {'Make_ID': 448,
#    'Make_Name': 'Toyota',
#    'Model_ID': 2466,
#    'Model_Name': 'Corolla Matrix'},
#   {'Make_ID': 448,
#    'Make_Name': 'Toyota',
#    'Model_ID': 2467,
#    'Model_Name': 'Tundra'},
#   {'Make_ID': 448,
#    'Make_Name': 'Toyota',
#    'Model_ID': 2468,
#    'Model_Name': 'Sienna'},
#   {'Make_ID': 448,
#    'Make_Name': 'Toyota',
#    'Model_ID': 2469,
#    'Model_Name': 'Camry'},
#   {'Make_ID': 448,
#    'Make_Name': 'Toyota',
#    'Model_ID': 2803,
#    'Model_Name': 'Camry Solara'},
#   {'Make_ID': 448,
#    'Make_Name': 'Toyota',
#    'Model_ID': 2827,
#    'Model_Name': 'Sequoia'},
#   {'Make_ID': 448,
#    'Make_Name': 'Toyota',
#    'Model_ID': 2933,
#    'Model_Name': 'Scion xD'},
#   {'Make_ID': 448,
#    'Make_Name': 'Toyota',
#    'Model_ID': 3005,
#    'Model_Name': 'Venza'},
#   {'Make_ID': 448,
#    'Make_Name': 'Toyota',
#    'Model_ID': 3155,
#    'Model_Name': 'FCHV-adv'},
#   {'Make_ID': 448,
#    'Make_Name': 'Toyota',
#    'Model_ID': 3644,
#    'Model_Name': 'Tercel'},
#   {'Make_ID': 448,
#    'Make_Name': 'Toyota',
#    'Model_ID': 3645,
#    'Model_Name': 'Celica'},
#   {'Make_ID': 448,
#    'Make_Name': 'Toyota',
#    'Model_ID': 3647,
#    'Model_Name': 'Supra'},
#   {'Make_ID': 448,
#    'Make_Name': 'Toyota',
#    'Model_ID': 3648,
#    'Model_Name': 'MR2'},
#   {'Make_ID': 448,
#    'Make_Name': 'Toyota',
#    'Model_ID': 3649,
#    'Model_Name': 'Paseo'},
#   {'Make_ID': 448,
#    'Make_Name': 'Toyota',
#    'Model_ID': 3650,
#    'Model_Name': 'Echo'},
#   {'Make_ID': 448,
#    'Make_Name': 'Toyota',
#    'Model_ID': 3655,
#    'Model_Name': 'Cressida'},
#   {'Make_ID': 448,
#    'Make_Name': 'Toyota',
#    'Model_ID': 3660,
#    'Model_Name': 'Cargo Van'},
#   {'Make_ID': 448,
#    'Make_Name': 'Toyota',
#    'Model_ID': 9373,
#    'Model_Name': 'Previa'},
#   {'Make_ID': 448,
#    'Make_Name': 'Toyota',
#    'Model_ID': 9374,
#    'Model_Name': 'T100'},
#   {'Make_ID': 448,
#    'Make_Name': 'Toyota',
#    'Model_ID': 10198,
#    'Model_Name': 'Mirai'},
#   {'Make_ID': 448,
#    'Make_Name': 'Toyota',
#    'Model_ID': 10241,
#    'Model_Name': 'Scion iQ'},
#   {'Make_ID': 448,
#    'Make_Name': 'Toyota',
#    'Model_ID': 11501,
#    'Model_Name': 'Scion iM'},
#   {'Make_ID': 448,
#    'Make_Name': 'Toyota',
#    'Model_ID': 13602,
#    'Model_Name': '86'},
#   {'Make_ID': 448,
#    'Make_Name': 'Toyota',
#    'Model_ID': 13603,
#    'Model_Name': 'Scion iA'},
#   {'Make_ID': 448,
#    'Make_Name': 'Toyota',
#    'Model_ID': 13822,
#    'Model_Name': 'Prius V'},
#   {'Make_ID': 448,
#    'Make_Name': 'Toyota',
#    'Model_ID': 13823,
#    'Model_Name': 'Prius C'},
#   {'Make_ID': 448,
#    'Make_Name': 'Toyota',
#    'Model_ID': 13824,
#    'Model_Name': 'Prius Plug-in'},
#   {'Make_ID': 448,
#    'Make_Name': 'Toyota',
#    'Model_ID': 14263,
#    'Model_Name': 'Pick-Up'},
#   {'Make_ID': 448,
#    'Make_Name': 'Toyota',
#    'Model_ID': 14264,
#    'Model_Name': 'Van'},
#   {'Make_ID': 448,
#    'Make_Name': 'Toyota',
#    'Model_ID': 14510,
#    'Model_Name': 'Starlet'},
#   {'Make_ID': 448,
#    'Make_Name': 'Toyota',
#    'Model_ID': 14551,
#    'Model_Name': 'Corona'},
#   {'Make_ID': 448,
#    'Make_Name': 'Toyota',
#    'Model_ID': 15800,
#    'Model_Name': 'COROLLA iM'},
#   {'Make_ID': 448,
#    'Make_Name': 'Toyota',
#    'Model_ID': 17213,
#    'Model_Name': 'C-HR'},
#   {'Make_ID': 448,
#    'Make_Name': 'Toyota',
#    'Model_ID': 21950,
#    'Model_Name': 'Prius Prime'},
#   {'Make_ID': 448,
#    'Make_Name': 'Toyota',
#    'Model_ID': 24949,
#    'Model_Name': 'Yaris iA'},
#   {'Make_ID': 448,
#    'Make_Name': 'Toyota',
#    'Model_ID': 28070,
#    'Model_Name': 'RAV4 Prime'},
#   {'Make_ID': 448,
#    'Make_Name': 'Toyota',
#    'Model_ID': 29274,
#    'Model_Name': 'Corolla Cross'},
#   {'Make_ID': 448,
#    'Make_Name': 'Toyota',
#    'Model_ID': 29364,
#    'Model_Name': 'GR86'},
#   {'Make_ID': 448,
#    'Make_Name': 'Toyota',
#    'Model_ID': 30041,
#    'Model_Name': 'bZ4X'},
#   {'Make_ID': 448,
#    'Make_Name': 'Toyota',
#    'Model_ID': 31077,
#    'Model_Name': 'Crown'},
#   {'Make_ID': 448,
#    'Make_Name': 'Toyota',
#    'Model_ID': 31079,
#    'Model_Name': 'GR Corolla'},
#   {'Make_ID': 448,
#    'Make_Name': 'Toyota',
#    'Model_ID': 32304,
#    'Model_Name': 'Grand Highlander'}]}

# %%
# Exercise 2 - gell all the manufacturer details for the model ford
ford_models = extract_vehicle_data("getmodelsformake","ford")
ford_models
# Out:
# Extracting data from https://vpic.nhtsa.dot.gov/api/vehicles/getmodelsformake/ford
# {'Count': 166,
#  'Message': 'Response returned successfully',
#  'SearchCriteria': 'Make:ford',
#  'Results': [{'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 1778,
#    'Model_Name': 'Crown Victoria'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 1779,
#    'Model_Name': 'Focus'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 1780,
#    'Model_Name': 'Fusion'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 1781,
#    'Model_Name': 'Mustang'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 1782,
#    'Model_Name': 'Taurus'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 1796,
#    'Model_Name': 'E-150'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 1797,
#    'Model_Name': 'Edge'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 1798,
#    'Model_Name': 'Escape'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 1799,
#    'Model_Name': 'Expedition'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 1800,
#    'Model_Name': 'Explorer'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 1801,
#    'Model_Name': 'F-150'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 1802,
#    'Model_Name': 'Flex'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 1803,
#    'Model_Name': 'Ranger'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 1804,
#    'Model_Name': 'Explorer Sport Trac'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 1805,
#    'Model_Name': 'F-250'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 1806,
#    'Model_Name': 'F-350'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 1807,
#    'Model_Name': 'F-450'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 1808,
#    'Model_Name': 'F-550'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 1809,
#    'Model_Name': 'F-650'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 1810,
#    'Model_Name': 'F-750'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 1811,
#    'Model_Name': 'Transit Connect'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 1817,
#    'Model_Name': 'E-250'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 1818,
#    'Model_Name': 'E-350'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 1819,
#    'Model_Name': 'E-450'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 1820,
#    'Model_Name': 'Expedition MAX'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 2345,
#    'Model_Name': 'Thunderbird'},
#   {'Make_ID': 460, 'Make_Name': 'Ford', 'Model_ID': 2346, 'Model_Name': 'GT'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 2347,
#    'Model_Name': 'Five Hundred'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 2370,
#    'Model_Name': 'Excursion'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 2379,
#    'Model_Name': 'Freestyle'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 2384,
#    'Model_Name': 'Freestar'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 2737,
#    'Model_Name': 'Motorhome Chassis'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 3160,
#    'Model_Name': 'Taurus X'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 3267,
#    'Model_Name': 'Fiesta'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 3410,
#    'Model_Name': 'Commercial Chassis'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 3462,
#    'Model_Name': 'C-Max'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 3608,
#    'Model_Name': 'Transit'},
#   {'Make_ID': 1237,
#    'Make_Name': 'Affordable Aluminum',
#    'Model_ID': 4563,
#    'Model_Name': 'Affordable Aluminum'},
#   {'Make_ID': 1298,
#    'Make_Name': 'Eagle Ford Tanks & Trailers LLC',
#    'Model_ID': 4645,
#    'Model_Name': 'Eagle Ford Tanks & Trailers LLC'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 5181,
#    'Model_Name': 'Escort'},
#   {'Make_ID': 460, 'Make_Name': 'Ford', 'Model_ID': 5182, 'Model_Name': 'ZX2'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 5264,
#    'Model_Name': 'Windstar'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 5342,
#    'Model_Name': 'E-550'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 5346,
#    'Model_Name': 'B-750'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 5361,
#    'Model_Name': 'F-800'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 5868,
#    'Model_Name': 'Explorer Sport'},
#   {'Make_ID': 2431,
#    'Make_Name': 'Milford Welding & Manufacturing',
#    'Model_ID': 6243,
#    'Model_Name': 'Milford Welding & Manufacturing Inc.'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 6703,
#    'Model_Name': 'Aspire'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 6730,
#    'Model_Name': 'Probe'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 6731,
#    'Model_Name': 'Contour'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 6825,
#    'Model_Name': 'Bronco'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 6857,
#    'Model_Name': 'Aerostar'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 7331,
#    'Model_Name': 'F-150 Heritage'},
#   {'Make_ID': 3609,
#    'Make_Name': 'Waterford Tank and Fabrication',
#    'Model_ID': 7985,
#    'Model_Name': 'Waterford Tank and Fabrication, LTD'},
#   {'Make_ID': 4265,
#    'Make_Name': 'Milford Pipe & Supply',
#    'Model_ID': 9047,
#    'Model_Name': 'Milford Pipe & Supply'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 9213,
#    'Model_Name': 'L8501'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 9214,
#    'Model_Name': 'LT8501'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 9215,
#    'Model_Name': 'L9501'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 9216,
#    'Model_Name': 'LT9501'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 9217,
#    'Model_Name': 'L8511'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 9218,
#    'Model_Name': 'LT8511'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 9219,
#    'Model_Name': 'L9511'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 9220,
#    'Model_Name': 'LT9511'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 9221,
#    'Model_Name': 'L8513'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 9222,
#    'Model_Name': 'LT8513'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 9223,
#    'Model_Name': 'L9513'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 9224,
#    'Model_Name': 'LT9513'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 9225,
#    'Model_Name': 'L9522'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 9226,
#    'Model_Name': 'LT9522'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 9227,
#    'Model_Name': 'A8513'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 9228,
#    'Model_Name': 'AT8513'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 9229,
#    'Model_Name': 'A9513'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 9230,
#    'Model_Name': 'AT9513'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 9231,
#    'Model_Name': 'A9522'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 9232,
#    'Model_Name': 'AT9522'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 9268,
#    'Model_Name': 'B800'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 9270,
#    'Model_Name': 'F-Super Duty'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 9272,
#    'Model_Name': 'F-700'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 9282,
#    'Model_Name': 'P700'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 9283,
#    'Model_Name': 'P800'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 9284,
#    'Model_Name': 'FT900'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 9285,
#    'Model_Name': 'L8000'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 9286,
#    'Model_Name': 'L9000'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 9287,
#    'Model_Name': 'LL9000'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 9288,
#    'Model_Name': 'LLA9000'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 9289,
#    'Model_Name': 'LLS9000'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 9290,
#    'Model_Name': 'LS8000'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 9291,
#    'Model_Name': 'LS9000'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 9292,
#    'Model_Name': 'LT8000'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 9293,
#    'Model_Name': 'LT9000'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 9294,
#    'Model_Name': 'LTS8000'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 9295,
#    'Model_Name': 'LTS9000'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 9296,
#    'Model_Name': 'LTL9000'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 9297,
#    'Model_Name': 'LTLA9000'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 9298,
#    'Model_Name': 'LTLS9000'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 9299,
#    'Model_Name': 'LA8000'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 9300,
#    'Model_Name': 'LA9000'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 9301,
#    'Model_Name': 'LTA9000'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 9302,
#    'Model_Name': 'LN7000'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 9303,
#    'Model_Name': 'LN8000'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 9304,
#    'Model_Name': 'LN9000'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 9305,
#    'Model_Name': 'LNT8000'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 9306,
#    'Model_Name': 'LNT9000'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 9307,
#    'Model_Name': 'CF8000'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 9308,
#    'Model_Name': 'CFT8000'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 9312,
#    'Model_Name': 'CF7000'},
#   {'Make_ID': 4533,
#    'Make_Name': 'Fords Trailer Sales',
#    'Model_ID': 9637,
#    'Model_Name': 'Fords Trailer Sales'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 10378,
#    'Model_Name': 'Festiva'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 11942,
#    'Model_Name': 'Low Cab Forward'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 13958,
#    'Model_Name': 'Tempo'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 13977,
#    'Model_Name': 'B600'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 13978,
#    'Model_Name': 'B700'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 13979,
#    'Model_Name': 'F-600'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 13980,
#    'Model_Name': 'Recreational Vehicle'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 13981,
#    'Model_Name': 'F-590'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 13983,
#    'Model_Name': 'P600'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 14148,
#    'Model_Name': 'CL9000'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 14149,
#    'Model_Name': 'CLT9000'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 14150,
#    'Model_Name': 'Bronco II'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 14152,
#    'Model_Name': 'FT800'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 14153,
#    'Model_Name': 'CT8000'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 14154,
#    'Model_Name': 'C800'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 14155,
#    'Model_Name': 'C8000'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 14196,
#    'Model_Name': 'Laser'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 14199,
#    'Model_Name': 'LTD'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 14614,
#    'Model_Name': 'Fairmont'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 14618,
#    'Model_Name': 'Granada'},
#   {'Make_ID': 5697,
#    'Make_Name': 'ASHFORD MFG',
#    'Model_ID': 14916,
#    'Model_Name': 'Travel Park'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 14930,
#    'Model_Name': "'34"},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 15160,
#    'Model_Name': 'CF6000'},
#   {'Make_ID': 5807,
#    'Make_Name': 'Ford Motor Company of New Zealand',
#    'Model_ID': 15193,
#    'Model_Name': '1500 Foldaway'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 15194,
#    'Model_Name': 'B7000'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 15195,
#    'Model_Name': 'C7000'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 15197,
#    'Model_Name': 'F7000'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 15198,
#    'Model_Name': 'F8000'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 15203,
#    'Model_Name': 'FT8000'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 15204,
#    'Model_Name': 'Courier'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 15205,
#    'Model_Name': 'B6000'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 15206,
#    'Model_Name': 'C600'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 15208,
#    'Model_Name': 'C700'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 15209,
#    'Model_Name': 'F6000'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 15223,
#    'Model_Name': 'LN600'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 15225,
#    'Model_Name': 'LN700'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 15251,
#    'Model_Name': 'L800'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 15252,
#    'Model_Name': 'LT800'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 15254,
#    'Model_Name': 'LN800'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 15255,
#    'Model_Name': 'LNT800'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 15273,
#    'Model_Name': 'E-100'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 15280,
#    'Model_Name': 'F-100'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 15291,
#    'Model_Name': 'CT800'},
#   {'Make_ID': 6163,
#    'Make_Name': 'Swinford Mfg',
#    'Model_ID': 16298,
#    'Model_Name': 'Swinford Mfg'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 17774,
#    'Model_Name': 'Ecosport'},
#   {'Make_ID': 6579,
#    'Make_Name': 'CRANFORD RADIATOR INC.',
#    'Model_ID': 17910,
#    'Model_Name': 'CRANFORD RADIATOR INC.'},
#   {'Make_ID': 6674,
#    'Make_Name': 'BRADFORD BUILT',
#    'Model_ID': 18064,
#    'Model_Name': 'BRADFORD BUILT'},
#   {'Make_ID': 6792,
#    'Make_Name': 'Stanford Customs',
#    'Model_ID': 18235,
#    'Model_Name': 'Malibu Sedan'},
#   {'Make_ID': 6792,
#    'Make_Name': 'Stanford Customs',
#    'Model_ID': 18236,
#    'Model_Name': 'Cordova Sedan'},
#   {'Make_ID': 6792,
#    'Make_Name': 'Stanford Customs',
#    'Model_ID': 18237,
#    'Model_Name': 'Classic Sedan'},
#   {'Make_ID': 8578,
#    'Make_Name': 'Bradford #1',
#    'Model_ID': 22551,
#    'Model_Name': 'Bradford #1'},
#   {'Make_ID': 8948,
#    'Make_Name': "Stafford's Trailers",
#    'Model_ID': 23075,
#    'Model_Name': "Stafford's Trailers"},
#   {'Make_ID': 9569,
#    'Make_Name': 'Medford Steel',
#    'Model_ID': 23878,
#    'Model_Name': 'Medford Steel'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 25742,
#    'Model_Name': 'Expedition EL'},
#   {'Make_ID': 10240,
#    'Make_Name': 'Affordable Trailers',
#    'Model_ID': 26910,
#    'Model_Name': 'Affordable Trailers'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 27411,
#    'Model_Name': 'Bronco Sport'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 27440,
#    'Model_Name': 'Mustang Mach-E'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 28967,
#    'Model_Name': 'Maverick'},
#   {'Make_ID': 460,
#    'Make_Name': 'Ford',
#    'Model_ID': 31551,
#    'Model_Name': 'GT MKII'}]}

# %%
# NOTE - consult the documentation for these exercises
